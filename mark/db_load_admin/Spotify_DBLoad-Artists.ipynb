# %% [markdown]
# ### Spotify EDA
# #### Load Artists

# %% [markdown]
# Get Artist details from Spotify for every artist in the database.
# Create a new table called "Artists" where each record is an artist.
# Primary key is the Spotify Artist URI.

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os
import sys
import json
import seaborn as sns

from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Table, Column, Integer, String, Float, MetaData
from sqlalchemy import create_engine
from sqlalchemy import and_
import sqlite3
from sqlalchemy.orm import sessionmaker

sys.path.append('../')
from spotify_api import get_spotify_data
from spotify_database import get_session, display_time

#TEMP
from spotify_api import parse_spotify_url, token, TokenAuth
import requests

from urllib.parse import urlencode

# %matplotlib inline

# %%
# !pip install ipywidgets 
# !jupyter nbextension enable --py widgetsnbextension
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager

# %%capture
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %% [markdown]
# ### Establish DataBase Connection

# %%
db_path = '../data/spotify_songs.db'

# Get sesion
session = get_session(db_path)
engine = create_engine('sqlite:///' + db_path)

# Get Classes
Playlists = getattr(get_session, "Playlists")
Tracks = getattr(get_session, "Tracks")
Artists = getattr(get_session, "Artists")

# %% [markdown]
# ### Establish Spotify API Connection

# %%
# Get URI for Artist, Track and Album for a song
rv = display_time(session.query(Playlists.track_name, 
                                Playlists.track_uri,
                                Playlists.artist_uri,
                                Playlists.album_uri).filter(Playlists.track_name=="Who Says").distinct().first)
rv
# Out:
# Time to Execute: 0.01 seconds
# ('Who Says',
#  'spotify:track:0HLWvLKQWpFdPhgk6ym58n',
#  'spotify:artist:0hEurMDQu99nJRq8pTxO14',
#  'spotify:album:1V5vQRMWTNGmqwxY8jMVou')

# %%
get_spotify_data(db_uri=rv.artist_uri, key='genres')
# Out:
# ['neo mellow', 'pop', 'pop rock', 'singer-songwriter']

# %%
# Create DB and Table if they don't exist


connection = engine.connect() #creates db if it doesn't exist
meta = MetaData()

# songs = Table(
#                 'songs', meta,
#                 Column('id', Integer, primary_key = True),
#                 Column('playlist_id', Integer),
#                 Column('pos', Integer), 
#                 Column('artist_name', String), 
#                 Column('track_uri', String),
#                 Column('artist_uri', String), 
#                 Column('track_name', String),
#                 Column('album_uri', String), 
#                 Column('duration_ms', String), 
#                 Column('album_name', String)
# )

tracks = Table(
                'tracks', meta,
                Column('track_uri', String, primary_key = True),
                Column('artist_uri', String),
                Column('danceability', Float),
                Column('energy', Float),
                Column('key', Integer),
                Column('loudness', Float),
                Column('mode', Integer),
                Column('speechiness', Float),
                Column('acousticness', Float),
                Column('instrumentalness', Float),
                Column('liveness', Float),
                Column('valence', Float),
                Column('tempo', Float),
                Column('duration_ms', Integer),
                Column('time_signature', Integer)
)

# artists = Table(
#                 'artists', meta,
#                 Column('artist_uri', String, primary_key = True),
#                 Column('followers', Integer),
#                 Column('genres', String),
#                 Column('artist_name', String),
#                 Column('artist_popularity', Integer)
# )

meta.create_all(engine)

# %%
# artists.drop(engine)

# %%
def build_artist_string(uri_list:list) -> str:
    rv_str = ''
    
    for u in uri_list:
        t_type, t_id = parse_spotify_url(u)
        if t_type != "artist":
            print("ERR: Only 'artist'-type uri's have features: {}".format(u))
            return False
        
        if rv_str == '':
            rv_str += t_id
        else:
            rv_str += ',' + t_id
            
    return rv_str

# %%
# get artists
from time import sleep
def get_artists(artist_uri_list:list) -> list:
    
    r_dict = {'ids': build_artist_string(artist_uri_list)}
        
    # build spotify url from db uri
    spotify_url = "https://api.spotify.com/v1/artists/"

    token()  # ensure token is valid
    response = requests.get(spotify_url, 
                            auth=TokenAuth('Bearer ' + token.token),
                            params=r_dict)
    
    if response.status_code == 429: # too many requests
        retry_value = response.headers.get('Retry-After')
        print("API limit.  Waiting {} seconds".format(retry_value))
        for s in tqdm(range(retry_value+1)):
            sleep(1)
            
        # resend request
        token()  # ensure token is valid
        response = requests.get(spotify_url,
                                auth=TokenAuth('Bearer ' + token.token),
                                params=r_dict)
                
    if response.status_code != 200:
        print("ERR: Unable to access Spotify data:  ERR:{}".format(response.status_code, url))
        return False
    
    return response.json().get('artists')

# %%
# get artists
from time import sleep
def get_artist(artist_uri:str) -> list:
    
    a_type, a_id = parse_spotify_url(artist_uri)
    
    if a_type!="artist":
        print("URI is not an artist URI: {}".format(artist_uri))
        return False
        
    # build spotify url from db uri
    spotify_url = "https://api.spotify.com/v1/artists/" + a_id

    token()  # ensure token is valid
    response = requests.get(spotify_url, 
                            auth=TokenAuth('Bearer ' + token.token))
    
    if response.status_code == 429: # too many requests
        retry_value = response.headers.get('Retry-After')
        print("API limit.  Waiting {} seconds".format(retry_value))
        for s in tqdm(range(retry_value+1)):
            sleep(1)
            
        # resend request
        token()  # ensure token is valid
        response = requests.get(spotify_url,
                                auth=TokenAuth('Bearer ' + token.token))
                
    if response.status_code != 200:
        print("ERR: Unable to access Spotify data:  ERR:{}".format(response.status_code, url))
        return False
    
    return response.json()

# %%
def load_artists(artists):
    Session = sessionmaker(bind = engine)
    session = Session()
    
    for a in artists:

        session.add(Artists( artist_uri          = a.get('uri'),
                             followers           = a.get('followers').get('total'),
                             genres              = ",".join(a.get('genres')),
                             artist_name         = a.get('name'),
                             artist_popularity   = a.get('popularity')
                           )
                   )

    try:
        session.commit()
    except Exception as e:
        session.rollback()
        
        # commit individually
        for i, a in enumerate(artists):
            session.add(Artists( artist_uri          = a.get('uri'),
                                 followers           = a.get('followers').get('total'),
                                 genres              = ",".join(a.get('genres')),
                                 artist_name         = a.get('name'),
                                 artist_popularity   = a.get('popularity')
                               )
                       )
            try:
                session.commit()
            except Exception as e:
                print("DUPLICATE {}: {} - {}".format(i, a.get('uri'), a.get('name') ))
                session.rollback()
        
    return len(artists)

# %%
def load_all(artists_list, blk_size:int=50):
    """
    Loads all artists db.
    Spotify only allows 50 tracks to be queried at once.
    """

    length = len(artists_list)
    if length==0:
        print("No records to load")
        return False
    
    start = 0
    for end in tqdm(range(blk_size,length+blk_size,blk_size)):
        if end>length:
            end=length

        # do query
        a = get_artists(artists_list[start:end])
        start = end

        # do load
        load_artists(a)

# %% [markdown]
# ### Load Artists
#
# First see what may already be loaded and only load items in the Songs DB that aren't already in the Artists DB

# %%
# get all unique tracks from playlists
all_artists = display_time(session.query(Playlists.artist_uri).distinct().all)
all_artists = [a.artist_uri for a in all_artists]

# make sure we aren't loading something already loaded
loaded_artists = display_time(session.query(Artists.artist_uri).all)
loaded_artists = [a.artist_uri for a in loaded_artists]

missing_artists = list(set(all_artists) - set(loaded_artists))

len(missing_artists)
# Out:
# Time to Execute: 111.91 seconds
# Time to Execute: 8.76 seconds
# 0

# %%
# WARNING!!!  Loads all values into DB
# Initial load will take several hours - 30 min est 
if len(missing_artists) > 0:
    load_all(missing_artists)
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# DUPLICATE 0: spotify:artist:6l6NgkV6IWYKlRN7jHCQmt - Stanley Myers

# %% [markdown]
# ### DB Corrections
# Some artists have new spotify ID numbers.  When you query the ID from the main playlist table, you get back a new ID number.
#
# This results in having Artist URI's in the playlist table that are not in the Artist table.
#
# To correct this, the playlist table is updated for the new uri.

# %%
# get the mismatch items
# routine will go through the list of
# mismatches and look each one up in the playlist table.  
# Then, the playlist URI will be retrieved.  If the artist name is the same,
# then the new URI from Spotify will be updated in the playlist table.

# %%
suspect_list = missing_artists

# %%
# Go through all suspect records.
# Get spotify details for the record's artist
# Make sure that the names are the same - if not, no update
# If names match - update the db_entry in the table and commit
updates = 0
for suspect in tqdm(suspect_list):
    
    db_artist_entries = display_time(session.query(Songs).filter(Songs.artist_uri==suspect).all)
    
    for db_entry in db_artist_entries:
        spotify_artist = get_artist(db_entry.artist_uri)
        spotify_artist_name = spotify_artist.get('name')
        spotify_artist_uri = spotify_artist.get('uri')

        if spotify_artist.get('uri') != db_entry.artist_uri:
            db_entry.artist_uri = spotify_artist_uri
            session.commit()
            updates += 1
        else:
            print("URIs matched: {} - {}".format(spotify_artist_uri, spotify_artist_name))

updates
# Out:
# HBox(children=(IntProgress(value=0, max=1994), HTML(value='')))
# Time to Execute: 44.2 seconds
# Time to Execute: 40.69 seconds
# Time to Execute: 41.98 seconds
# Time to Execute: 41.5 seconds
# Time to Execute: 39.69 seconds
# Time to Execute: 40.53 seconds
# Time to Execute: 40.0 seconds
# Time to Execute: 38.49 seconds
# Time to Execute: 42.27 seconds
# Time to Execute: 39.58 seconds
# Time to Execute: 40.39 seconds
# Time to Execute: 39.44 seconds
# Time to Execute: 38.98 seconds
# Time to Execute: 38.93 seconds
# Time to Execute: 41.39 seconds
# Time to Execute: 39.13 seconds
# Time to Execute: 40.12 seconds
# Time to Execute: 39.91 seconds
# Time to Execute: 41.01 seconds
# Time to Execute: 40.99 seconds
# Time to Execute: 44.73 seconds
# Time to Execute: 50.87 seconds
# Time to Execute: 52.98 seconds
# Time to Execute: 48.56 seconds
# Time to Execute: 52.15 seconds
# Time to Execute: 55.08 seconds
# Time to Execute: 50.33 seconds
# Time to Execute: 53.1 seconds
# Time to Execute: 51.8 seconds
# Time to Execute: 51.83 seconds
# Time to Execute: 54.49 seconds
# token():INFO:   Token refreshed
# Time to Execute: 54.69 seconds
# Time to Execute: 55.55 seconds
# Time to Execute: 52.04 seconds
# Time to Execute: 51.88 seconds
# Time to Execute: 55.79 seconds
# Time to Execute: 52.24 seconds
# Time to Execute: 54.75 seconds
# Time to Execute: 40.0 seconds
# Time to Execute: 47.99 seconds
# Time to Execute: 46.59 seconds
# Time to Execute: 43.98 seconds
# Time to Execute: 47.22 seconds
# Time to Execute: 52.48 seconds
# Time to Execute: 45.55 seconds
# Time to Execute: 42.38 seconds
# Time to Execute: 47.9 seconds
# Time to Execute: 45.17 seconds
# Time to Execute: 53.35 seconds
# Time to Execute: 52.8 seconds
# Time to Execute: 49.98 seconds
# Time to Execute: 49.55 seconds
# Time to Execute: 54.73 seconds
# Time to Execute: 48.47 seconds
# Time to Execute: 55.21 seconds
# Time to Execute: 47.68 seconds
# Time to Execute: 52.61 seconds
# Time to Execute: 52.36 seconds
# Time to Execute: 50.84 seconds
# Time to Execute: 51.34 seconds
# Time to Execute: 46.54 seconds
# Time to Execute: 42.22 seconds
# Time to Execute: 46.6 seconds
# Time to Execute: 51.04 seconds
# Time to Execute: 51.25 seconds
# Time to Execute: 53.45 seconds
# Time to Execute: 52.02 seconds
# Time to Execute: 52.48 seconds
# Time to Execute: 48.73 seconds
# Time to Execute: 48.72 seconds
# Time to Execute: 47.98 seconds
# Time to Execute: 52.71 seconds
# Time to Execute: 51.4 seconds
# Time to Execute: 51.63 seconds
# Time to Execute: 52.58 seconds
# Time to Execute: 47.42 seconds
# Time to Execute: 55.99 seconds
# Time to Execute: 53.98 seconds
# Time to Execute: 48.87 seconds
# Time to Execute: 51.51 seconds
# Time to Execute: 56.58 seconds
# Time to Execute: 47.22 seconds
# Time to Execute: 45.19 seconds
# Time to Execute: 42.89 seconds
# Time to Execute: 49.21 seconds
# Time to Execute: 42.33 seconds
# Time to Execute: 41.03 seconds
# Time to Execute: 47.64 seconds
# Time to Execute: 50.12 seconds
# Time to Execute: 43.16 seconds
# Time to Execute: 43.05 seconds
# Time to Execute: 41.98 seconds
# Time to Execute: 40.7 seconds
# Time to Execute: 46.89 seconds
# Time to Execute: 43.49 seconds
# Time to Execute: 45.45 seconds
# Time to Execute: 46.73 seconds
# Time to Execute: 42.89 seconds
# Time to Execute: 44.39 seconds
# Time to Execute: 50.84 seconds
# Time to Execute: 48.07 seconds
# token():INFO:   Token refreshed
# Time to Execute: 49.19 seconds
# Time to Execute: 46.35 seconds
# Time to Execute: 45.96 seconds
# Time to Execute: 44.76 seconds
# Time to Execute: 40.83 seconds
# Time to Execute: 48.98 seconds
# Time to Execute: 50.4 seconds
# Time to Execute: 44.49 seconds
# Time to Execute: 46.24 seconds
# Time to Execute: 51.77 seconds
# Time to Execute: 48.18 seconds
# Time to Execute: 50.12 seconds
# Time to Execute: 47.57 seconds
# Time to Execute: 52.78 seconds
# Time to Execute: 45.32 seconds
# Time to Execute: 51.22 seconds
# Time to Execute: 48.44 seconds
# Time to Execute: 52.47 seconds
# Time to Execute: 47.05 seconds
# Time to Execute: 54.04 seconds
# Time to Execute: 48.81 seconds
# Time to Execute: 55.47 seconds
# Time to Execute: 47.73 seconds
# Time to Execute: 47.28 seconds
# Time to Execute: 53.29 seconds
# Time to Execute: 46.2 seconds
# Time to Execute: 46.59 seconds
# Time to Execute: 50.21 seconds
# Time to Execute: 43.2 seconds
# Time to Execute: 46.75 seconds
# Time to Execute: 45.3 seconds
# Time to Execute: 50.49 seconds
# Time to Execute: 47.55 seconds
# Time to Execute: 50.06 seconds
# Time to Execute: 47.91 seconds
# Time to Execute: 46.65 seconds
# Time to Execute: 52.15 seconds
# Time to Execute: 48.02 seconds
# Time to Execute: 52.45 seconds
# Time to Execute: 49.13 seconds
# Time to Execute: 48.55 seconds
# Time to Execute: 47.01 seconds
# Time to Execute: 50.86 seconds
# Time to Execute: 51.21 seconds
# Time to Execute: 45.77 seconds
# Time to Execute: 50.6 seconds
# Time to Execute: 47.25 seconds
# Time to Execute: 44.98 seconds
# Time to Execute: 53.84 seconds
# Time to Execute: 50.15 seconds
# Time to Execute: 53.34 seconds
# Time to Execute: 48.01 seconds
# Time to Execute: 51.25 seconds
# Time to Execute: 48.27 seconds
# Time to Execute: 50.71 seconds
# Time to Execute: 45.2 seconds
# Time to Execute: 48.04 seconds
# Time to Execute: 41.76 seconds
# Time to Execute: 46.98 seconds
# Time to Execute: 42.38 seconds
# Time to Execute: 42.58 seconds
# Time to Execute: 46.31 seconds
# Time to Execute: 47.87 seconds
# Time to Execute: 44.56 seconds
# Time to Execute: 46.38 seconds
# Time to Execute: 49.67 seconds
# Time to Execute: 52.4 seconds
# Time to Execute: 48.17 seconds
# token():INFO:   Token refreshed
# Time to Execute: 43.87 seconds
# Time to Execute: 47.76 seconds
# Time to Execute: 46.17 seconds
# Time to Execute: 42.72 seconds
# Time to Execute: 47.22 seconds
# Time to Execute: 47.47 seconds
# Time to Execute: 46.98 seconds
# Time to Execute: 47.93 seconds
# Time to Execute: 49.85 seconds
# Time to Execute: 46.89 seconds
# Time to Execute: 48.85 seconds
# Time to Execute: 50.91 seconds
# Time to Execute: 40.83 seconds
# Time to Execute: 43.12 seconds
# Time to Execute: 49.91 seconds
# Time to Execute: 49.24 seconds
# Time to Execute: 49.72 seconds
# Time to Execute: 50.2 seconds
# Time to Execute: 49.81 seconds
# Time to Execute: 46.75 seconds
# Time to Execute: 46.78 seconds
# Time to Execute: 46.19 seconds
# Time to Execute: 46.23 seconds
# Time to Execute: 41.69 seconds
# Time to Execute: 40.29 seconds
# Time to Execute: 40.75 seconds
# Time to Execute: 43.85 seconds
# Time to Execute: 47.85 seconds
# Time to Execute: 45.11 seconds
# Time to Execute: 45.68 seconds
# Time to Execute: 51.43 seconds
# Time to Execute: 38.93 seconds
# Time to Execute: 42.86 seconds
# Time to Execute: 46.25 seconds
# Time to Execute: 44.54 seconds
# Time to Execute: 50.95 seconds
# Time to Execute: 48.69 seconds
# Time to Execute: 47.72 seconds
# Time to Execute: 51.24 seconds
# Time to Execute: 50.09 seconds
# Time to Execute: 51.17 seconds
# Time to Execute: 50.24 seconds
# Time to Execute: 44.27 seconds
# Time to Execute: 47.75 seconds
# Time to Execute: 48.14 seconds
# Time to Execute: 52.59 seconds
# Time to Execute: 49.35 seconds
# Time to Execute: 45.42 seconds
# Time to Execute: 47.14 seconds
# Time to Execute: 50.77 seconds
# Time to Execute: 50.06 seconds
# Time to Execute: 48.46 seconds
# Time to Execute: 51.43 seconds
# Time to Execute: 51.66 seconds
# Time to Execute: 49.41 seconds
# Time to Execute: 49.75 seconds
# Time to Execute: 53.24 seconds
# Time to Execute: 53.48 seconds
# Time to Execute: 45.53 seconds
# Time to Execute: 50.43 seconds
# Time to Execute: 46.64 seconds
# Time to Execute: 46.07 seconds
# Time to Execute: 47.65 seconds
# Time to Execute: 49.09 seconds
# Time to Execute: 43.1 seconds
# Time to Execute: 51.15 seconds
# Time to Execute: 49.08 seconds
# Time to Execute: 49.77 seconds
# Time to Execute: 48.99 seconds
# Time to Execute: 51.4 seconds
# token():INFO:   Token refreshed
# Time to Execute: 47.06 seconds
# Time to Execute: 50.19 seconds
# Time to Execute: 48.28 seconds
# Time to Execute: 46.6 seconds
# Time to Execute: 49.44 seconds
# Time to Execute: 50.62 seconds
# Time to Execute: 46.95 seconds
# Time to Execute: 50.65 seconds
# Time to Execute: 50.62 seconds
# Time to Execute: 49.82 seconds
# Time to Execute: 51.0 seconds
# Time to Execute: 51.78 seconds
# Time to Execute: 45.76 seconds
# Time to Execute: 50.81 seconds
# Time to Execute: 49.2 seconds
# Time to Execute: 43.7 seconds
# Time to Execute: 47.72 seconds
# Time to Execute: 48.06 seconds
# Time to Execute: 47.32 seconds
# Time to Execute: 47.55 seconds
# Time to Execute: 46.28 seconds
# Time to Execute: 47.48 seconds
# Time to Execute: 48.69 seconds
# Time to Execute: 47.32 seconds
# Time to Execute: 45.44 seconds
# Time to Execute: 50.11 seconds
# Time to Execute: 48.53 seconds
# Time to Execute: 43.96 seconds
# Time to Execute: 49.71 seconds
# Time to Execute: 49.74 seconds
# Time to Execute: 48.02 seconds
# Time to Execute: 53.21 seconds
# Time to Execute: 45.46 seconds
# Time to Execute: 50.05 seconds
# Time to Execute: 53.37 seconds
# Time to Execute: 44.97 seconds
# Time to Execute: 50.96 seconds
# Time to Execute: 46.74 seconds
# Time to Execute: 44.55 seconds
# Time to Execute: 48.11 seconds
# Time to Execute: 45.99 seconds
# Time to Execute: 51.48 seconds
# Time to Execute: 47.53 seconds
# Time to Execute: 47.77 seconds
# Time to Execute: 51.8 seconds
# Time to Execute: 47.02 seconds
# Time to Execute: 44.03 seconds
# Time to Execute: 50.32 seconds
# Time to Execute: 47.75 seconds
# Time to Execute: 53.72 seconds
# Time to Execute: 56.45 seconds
# Time to Execute: 49.99 seconds
# Time to Execute: 49.99 seconds
# Time to Execute: 54.23 seconds
# Time to Execute: 51.07 seconds
# Time to Execute: 44.8 seconds
# Time to Execute: 49.41 seconds
# Time to Execute: 50.07 seconds
# Time to Execute: 50.75 seconds
# Time to Execute: 45.96 seconds
# Time to Execute: 52.5 seconds
# Time to Execute: 47.3 seconds
# Time to Execute: 52.64 seconds
# Time to Execute: 47.99 seconds
# Time to Execute: 53.35 seconds
# Time to Execute: 52.52 seconds
# Time to Execute: 49.6 seconds
# token():INFO:   Token refreshed
# Time to Execute: 49.84 seconds
# Time to Execute: 45.36 seconds
# Time to Execute: 40.58 seconds
# Time to Execute: 48.81 seconds
# Time to Execute: 44.03 seconds
# Time to Execute: 44.53 seconds
# Time to Execute: 50.45 seconds
# Time to Execute: 43.54 seconds
# Time to Execute: 39.11 seconds
# Time to Execute: 41.25 seconds
# Time to Execute: 45.1 seconds
# Time to Execute: 49.56 seconds
# Time to Execute: 50.74 seconds
# Time to Execute: 48.45 seconds
# Time to Execute: 47.68 seconds
# Time to Execute: 47.03 seconds
# Time to Execute: 45.68 seconds
# Time to Execute: 50.04 seconds
# Time to Execute: 51.99 seconds
# Time to Execute: 45.08 seconds
# Time to Execute: 46.78 seconds
# Time to Execute: 47.16 seconds
# Time to Execute: 43.69 seconds
# Time to Execute: 49.4 seconds
# Time to Execute: 43.61 seconds
# Time to Execute: 42.69 seconds
# Time to Execute: 47.94 seconds
# Time to Execute: 43.33 seconds
# Time to Execute: 45.29 seconds
# Time to Execute: 42.01 seconds
# Time to Execute: 41.2 seconds
# Time to Execute: 48.06 seconds
# Time to Execute: 48.1 seconds
# Time to Execute: 45.47 seconds
# Time to Execute: 46.42 seconds
# Time to Execute: 42.2 seconds
# Time to Execute: 46.33 seconds
# Time to Execute: 47.86 seconds
# Time to Execute: 50.57 seconds
# Time to Execute: 41.22 seconds
# Time to Execute: 49.03 seconds
# Time to Execute: 50.31 seconds
# Time to Execute: 50.29 seconds
# Time to Execute: 46.33 seconds
# Time to Execute: 48.4 seconds
# Time to Execute: 52.03 seconds
# Time to Execute: 49.69 seconds
# Time to Execute: 53.35 seconds
# Time to Execute: 53.5 seconds
# Time to Execute: 49.98 seconds
# Time to Execute: 53.0 seconds
# Time to Execute: 49.92 seconds
# Time to Execute: 51.06 seconds
# Time to Execute: 53.23 seconds
# Time to Execute: 46.32 seconds
# Time to Execute: 49.2 seconds
# Time to Execute: 52.05 seconds
# Time to Execute: 54.54 seconds
# Time to Execute: 50.36 seconds
# Time to Execute: 48.02 seconds
# Time to Execute: 49.87 seconds
# Time to Execute: 53.55 seconds
# Time to Execute: 53.27 seconds
# Time to Execute: 51.23 seconds
# Time to Execute: 49.45 seconds
# Time to Execute: 51.39 seconds
# Time to Execute: 49.55 seconds
# Time to Execute: 50.19 seconds
# Time to Execute: 48.02 seconds
# Time to Execute: 50.86 seconds
# token():INFO:   Token refreshed
# Time to Execute: 46.3 seconds
# Time to Execute: 47.4 seconds
# Time to Execute: 47.72 seconds
# Time to Execute: 48.86 seconds
# Time to Execute: 42.0 seconds
# Time to Execute: 46.48 seconds
# Time to Execute: 47.99 seconds
# Time to Execute: 48.25 seconds
# Time to Execute: 42.38 seconds
# Time to Execute: 36.34 seconds
# Time to Execute: 34.32 seconds
# Time to Execute: 47.56 seconds
# Time to Execute: 47.08 seconds
# Time to Execute: 46.84 seconds
# Time to Execute: 43.57 seconds
# Time to Execute: 45.68 seconds
# Time to Execute: 43.91 seconds
# Time to Execute: 47.29 seconds
# Time to Execute: 42.62 seconds
# Time to Execute: 46.07 seconds
# Time to Execute: 46.43 seconds
# Time to Execute: 42.3 seconds
# Time to Execute: 43.11 seconds
# Time to Execute: 42.72 seconds
# Time to Execute: 40.85 seconds
# Time to Execute: 41.21 seconds
# Time to Execute: 37.51 seconds
# Time to Execute: 43.66 seconds
# Time to Execute: 46.53 seconds
# Time to Execute: 45.29 seconds
# Time to Execute: 43.89 seconds
# Time to Execute: 46.67 seconds
# Time to Execute: 44.77 seconds
# Time to Execute: 47.03 seconds
# Time to Execute: 48.8 seconds
# Time to Execute: 52.36 seconds
# Time to Execute: 50.05 seconds
# Time to Execute: 43.96 seconds
# Time to Execute: 45.69 seconds
# Time to Execute: 46.83 seconds
# Time to Execute: 46.84 seconds
# Time to Execute: 48.24 seconds
# Time to Execute: 50.59 seconds
# Time to Execute: 51.71 seconds
# Time to Execute: 49.51 seconds
# Time to Execute: 43.81 seconds
# Time to Execute: 43.76 seconds
# Time to Execute: 47.81 seconds
# Time to Execute: 44.84 seconds
# Time to Execute: 51.68 seconds
# Time to Execute: 46.35 seconds
# Time to Execute: 48.56 seconds
# Time to Execute: 43.4 seconds
# Time to Execute: 47.88 seconds
# Time to Execute: 40.61 seconds
# Time to Execute: 45.69 seconds
# Time to Execute: 47.32 seconds
# Time to Execute: 42.37 seconds
# Time to Execute: 49.7 seconds
# Time to Execute: 43.45 seconds
# Time to Execute: 49.93 seconds
# Time to Execute: 41.35 seconds
# Time to Execute: 40.36 seconds
# Time to Execute: 44.69 seconds
# Time to Execute: 46.9 seconds
# Time to Execute: 41.62 seconds
# Time to Execute: 44.98 seconds
# Time to Execute: 39.15 seconds
# Time to Execute: 45.25 seconds
# Time to Execute: 44.79 seconds
# Time to Execute: 46.33 seconds
# Time to Execute: 44.58 seconds
# Time to Execute: 43.25 seconds
# Time to Execute: 41.32 seconds
# Time to Execute: 44.51 seconds
# Time to Execute: 41.96 seconds
# Time to Execute: 40.22 seconds
# token():INFO:   Token refreshed
# Time to Execute: 42.21 seconds
# Time to Execute: 48.24 seconds
# Time to Execute: 44.7 seconds
# Time to Execute: 48.97 seconds
# Time to Execute: 47.22 seconds
# Time to Execute: 52.26 seconds
# Time to Execute: 47.39 seconds
# Time to Execute: 45.23 seconds
# Time to Execute: 50.46 seconds
# Time to Execute: 44.86 seconds
# Time to Execute: 48.88 seconds
# Time to Execute: 44.19 seconds
# Time to Execute: 44.62 seconds
# Time to Execute: 46.47 seconds
# Time to Execute: 48.41 seconds
# Time to Execute: 48.36 seconds
# Time to Execute: 46.51 seconds
# Time to Execute: 39.78 seconds
# Time to Execute: 48.85 seconds
# Time to Execute: 45.97 seconds
# Time to Execute: 45.89 seconds
# Time to Execute: 48.09 seconds
# Time to Execute: 47.35 seconds
# Time to Execute: 35.76 seconds
# Time to Execute: 8.31 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.97 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 7.09 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.67 seconds
# Time to Execute: 6.67 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.66 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 7.0 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.65 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 7.59 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 7.08 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.97 seconds
# Time to Execute: 7.0 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 7.0 seconds
# Time to Execute: 7.02 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 7.04 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.65 seconds
# Time to Execute: 9.07 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 18.75 seconds
# Time to Execute: 21.65 seconds
# Time to Execute: 7.38 seconds
# Time to Execute: 6.67 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.98 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.8 seconds
# token():INFO:   Token refreshed
# Time to Execute: 6.79 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.67 seconds
# Time to Execute: 7.25 seconds
# Time to Execute: 20.11 seconds
# Time to Execute: 9.0 seconds
# Time to Execute: 8.07 seconds
# Time to Execute: 8.05 seconds
# Time to Execute: 10.14 seconds
# Time to Execute: 13.51 seconds
# Time to Execute: 12.18 seconds
# Time to Execute: 10.56 seconds
# Time to Execute: 9.71 seconds
# Time to Execute: 9.39 seconds
# Time to Execute: 9.36 seconds
# Time to Execute: 9.39 seconds
# Time to Execute: 9.95 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.64 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 7.11 seconds
# Time to Execute: 9.26 seconds
# Time to Execute: 39.24 seconds
# Time to Execute: 35.53 seconds
# Time to Execute: 37.5 seconds
# Time to Execute: 37.79 seconds
# Time to Execute: 36.62 seconds
# Time to Execute: 37.07 seconds
# Time to Execute: 36.15 seconds
# Time to Execute: 45.74 seconds
# Time to Execute: 43.67 seconds
# Time to Execute: 42.31 seconds
# Time to Execute: 49.79 seconds
# Time to Execute: 47.54 seconds
# Time to Execute: 47.82 seconds
# Time to Execute: 46.57 seconds
# Time to Execute: 48.6 seconds
# Time to Execute: 45.23 seconds
# Time to Execute: 46.38 seconds
# Time to Execute: 50.87 seconds
# Time to Execute: 50.98 seconds
# Time to Execute: 45.51 seconds
# Time to Execute: 44.63 seconds
# Time to Execute: 47.41 seconds
# Time to Execute: 48.39 seconds
# Time to Execute: 45.4 seconds
# Time to Execute: 48.44 seconds
# Time to Execute: 50.33 seconds
# Time to Execute: 49.25 seconds
# Time to Execute: 42.64 seconds
# Time to Execute: 45.95 seconds
# Time to Execute: 48.39 seconds
# Time to Execute: 50.74 seconds
# Time to Execute: 44.31 seconds
# Time to Execute: 45.68 seconds
# Time to Execute: 41.09 seconds
# Time to Execute: 48.25 seconds
# Time to Execute: 46.51 seconds
# Time to Execute: 48.72 seconds
# Time to Execute: 40.61 seconds
# Time to Execute: 46.68 seconds
# Time to Execute: 47.42 seconds
# Time to Execute: 42.35 seconds
# Time to Execute: 45.57 seconds
# Time to Execute: 43.4 seconds
# Time to Execute: 43.63 seconds
# Time to Execute: 42.72 seconds
# Time to Execute: 40.96 seconds
# Time to Execute: 43.38 seconds
# Time to Execute: 47.22 seconds
# Time to Execute: 49.77 seconds
# Time to Execute: 49.12 seconds
# Time to Execute: 50.79 seconds
# Time to Execute: 47.81 seconds
# Time to Execute: 51.26 seconds
# Time to Execute: 48.55 seconds
# Time to Execute: 47.76 seconds
# Time to Execute: 38.79 seconds
# Time to Execute: 43.43 seconds
# Time to Execute: 44.54 seconds
# Time to Execute: 40.21 seconds
# token():INFO:   Token refreshed
# Time to Execute: 43.69 seconds
# Time to Execute: 46.74 seconds
# Time to Execute: 38.12 seconds
# Time to Execute: 43.01 seconds
# Time to Execute: 46.79 seconds
# Time to Execute: 40.28 seconds
# Time to Execute: 40.3 seconds
# Time to Execute: 43.42 seconds
# Time to Execute: 42.65 seconds
# Time to Execute: 36.26 seconds
# Time to Execute: 42.9 seconds
# Time to Execute: 44.54 seconds
# Time to Execute: 23.98 seconds
# Time to Execute: 7.81 seconds
# Time to Execute: 7.05 seconds
# Time to Execute: 7.07 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.98 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 7.0 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.98 seconds
# Time to Execute: 7.0 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.66 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 7.45 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.66 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.97 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.67 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.65 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.67 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 7.17 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.67 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.66 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 7.0 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.66 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.66 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.77 seconds
# token():INFO:   Token refreshed
# Time to Execute: 6.79 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 7.04 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 7.19 seconds
# Time to Execute: 7.14 seconds
# Time to Execute: 7.12 seconds
# Time to Execute: 7.32 seconds
# Time to Execute: 10.45 seconds
# Time to Execute: 7.2 seconds
# Time to Execute: 7.21 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 7.07 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 7.05 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 7.02 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 7.03 seconds
# Time to Execute: 7.34 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 7.01 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.97 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 7.06 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 7.0 seconds
# Time to Execute: 6.97 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.98 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 7.32 seconds
# Time to Execute: 7.24 seconds
# Time to Execute: 7.11 seconds
# Time to Execute: 7.0 seconds
# Time to Execute: 7.05 seconds
# Time to Execute: 7.01 seconds
# Time to Execute: 7.01 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 7.01 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 7.01 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 7.07 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 7.0 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.97 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 7.04 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 7.04 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.98 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 7.01 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.8 seconds
# token():INFO:   Token refreshed
# Time to Execute: 6.87 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 7.11 seconds
# Time to Execute: 7.09 seconds
# Time to Execute: 7.08 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.67 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.67 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 7.0 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.97 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 7.12 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.97 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.99 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.66 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 7.3 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.73 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 7.21 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 7.19 seconds
# Time to Execute: 7.04 seconds
# Time to Execute: 6.96 seconds
# Time to Execute: 7.84 seconds
# Time to Execute: 36.1 seconds
# token():INFO:   Token refreshed
# Time to Execute: 29.33 seconds
# Time to Execute: 12.3 seconds
# Time to Execute: 13.88 seconds
# Time to Execute: 31.6 seconds
# Time to Execute: 64.08 seconds
# Time to Execute: 62.96 seconds
# Time to Execute: 63.07 seconds
# Time to Execute: 57.94 seconds
# Time to Execute: 11.56 seconds
# Time to Execute: 7.2 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.79 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.97 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 7.08 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.89 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.91 seconds
# Time to Execute: 6.69 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.94 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 7.16 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.68 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.83 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.72 seconds
# Time to Execute: 6.76 seconds
# Time to Execute: 6.77 seconds
# Time to Execute: 7.02 seconds
# Time to Execute: 7.03 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 6.74 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.95 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.87 seconds
# Time to Execute: 6.78 seconds
# Time to Execute: 6.92 seconds
# Time to Execute: 6.81 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.8 seconds
# Time to Execute: 6.85 seconds
# Time to Execute: 6.86 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.82 seconds
# Time to Execute: 6.71 seconds
# Time to Execute: 6.75 seconds
# Time to Execute: 6.7 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.93 seconds
# Time to Execute: 6.84 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 6.9 seconds
# Time to Execute: 7.57 seconds
# Time to Execute: 13.2 seconds
# Time to Execute: 7.98 seconds
# Time to Execute: 18.23 seconds
# Time to Execute: 10.78 seconds
# Time to Execute: 10.0 seconds
# Time to Execute: 7.53 seconds
# Time to Execute: 7.07 seconds
# Time to Execute: 15.5 seconds
# Time to Execute: 7.2 seconds
# Time to Execute: 6.88 seconds
# Time to Execute: 25.28 seconds
# Time to Execute: 16.74 seconds
# Time to Execute: 25.76 seconds
# Time to Execute: 13.69 seconds
# Time to Execute: 11.86 seconds
# Time to Execute: 13.85 seconds
# Time to Execute: 33.65 seconds
# Time to Execute: 15.26 seconds
# Time to Execute: 20.02 seconds
# Time to Execute: 56.17 seconds
# Time to Execute: 19.7 seconds
# Time to Execute: 55.93 seconds
# Time to Execute: 18.99 seconds
# Time to Execute: 50.76 seconds
# Time to Execute: 18.36 seconds
# Time to Execute: 55.51 seconds
# Time to Execute: 19.0 seconds
# Time to Execute: 53.76 seconds
# Time to Execute: 18.37 seconds
# Time to Execute: 53.66 seconds
# Time to Execute: 17.9 seconds
# Time to Execute: 57.41 seconds
# Time to Execute: 16.89 seconds
# Time to Execute: 55.76 seconds
# Time to Execute: 17.08 seconds
# Time to Execute: 57.59 seconds
# Time to Execute: 16.89 seconds
# Time to Execute: 57.7 seconds
# Time to Execute: 17.54 seconds
# Time to Execute: 57.44 seconds
# Time to Execute: 18.76 seconds
# Time to Execute: 54.5 seconds
# Time to Execute: 17.81 seconds
# Time to Execute: 58.21 seconds
# Time to Execute: 18.82 seconds
# Time to Execute: 53.66 seconds
# Time to Execute: 20.06 seconds
# Time to Execute: 50.8 seconds
# Time to Execute: 21.43 seconds
# Time to Execute: 52.74 seconds
# Time to Execute: 24.37 seconds
# Time to Execute: 51.81 seconds
# Time to Execute: 27.32 seconds
# Time to Execute: 50.11 seconds
# Time to Execute: 25.1 seconds
# Time to Execute: 47.15 seconds
# Time to Execute: 29.5 seconds
# Time to Execute: 47.91 seconds
# Time to Execute: 30.41 seconds
# Time to Execute: 44.81 seconds
# Time to Execute: 30.49 seconds
# Time to Execute: 42.75 seconds
# Time to Execute: 34.5 seconds
# token():INFO:   Token refreshed
# Time to Execute: 41.92 seconds
# Time to Execute: 30.58 seconds
# Time to Execute: 30.43 seconds
# Time to Execute: 50.19 seconds
# Time to Execute: 30.56 seconds
# Time to Execute: 51.55 seconds
# Time to Execute: 27.39 seconds
# Time to Execute: 51.89 seconds
# Time to Execute: 24.22 seconds
# Time to Execute: 51.98 seconds
# Time to Execute: 22.57 seconds
# Time to Execute: 50.53 seconds
# Time to Execute: 22.55 seconds
# Time to Execute: 54.08 seconds
# Time to Execute: 23.38 seconds
# Time to Execute: 50.42 seconds
# Time to Execute: 23.66 seconds
# Time to Execute: 52.6 seconds
# Time to Execute: 25.13 seconds
# Time to Execute: 53.94 seconds
# Time to Execute: 29.97 seconds
# Time to Execute: 45.34 seconds
# Time to Execute: 29.84 seconds
# Time to Execute: 43.09 seconds
# Time to Execute: 37.29 seconds
# Time to Execute: 40.82 seconds
# Time to Execute: 36.96 seconds
# Time to Execute: 36.96 seconds
# Time to Execute: 41.49 seconds
# Time to Execute: 36.61 seconds
# Time to Execute: 47.15 seconds
# Time to Execute: 33.39 seconds
# Time to Execute: 45.08 seconds
# Time to Execute: 31.31 seconds
# Time to Execute: 51.84 seconds
# Time to Execute: 25.42 seconds
# Time to Execute: 50.51 seconds
# Time to Execute: 26.02 seconds
# Time to Execute: 54.23 seconds
# Time to Execute: 26.72 seconds
# Time to Execute: 58.9 seconds
# Time to Execute: 17.47 seconds
# Time to Execute: 58.05 seconds
# Time to Execute: 57.41 seconds
# Time to Execute: 58.47 seconds
# Time to Execute: 58.96 seconds
# Time to Execute: 59.64 seconds
# Time to Execute: 59.06 seconds
# Time to Execute: 59.44 seconds
# Time to Execute: 60.33 seconds
# Time to Execute: 59.35 seconds
# Time to Execute: 56.39 seconds
# Time to Execute: 59.85 seconds
# Time to Execute: 61.06 seconds
# Time to Execute: 62.07 seconds
# Time to Execute: 58.04 seconds
# Time to Execute: 57.7 seconds
# Time to Execute: 59.56 seconds
# Time to Execute: 61.3 seconds
# Time to Execute: 59.5 seconds
# Time to Execute: 57.65 seconds
# Time to Execute: 59.3 seconds
# Time to Execute: 56.45 seconds
# Time to Execute: 58.67 seconds
# Time to Execute: 54.75 seconds
# Time to Execute: 53.45 seconds
# Time to Execute: 58.66 seconds
# Time to Execute: 59.48 seconds
# Time to Execute: 57.18 seconds
# Time to Execute: 58.32 seconds
# token():INFO:   Token refreshed
# Time to Execute: 54.55 seconds
# Time to Execute: 39.09 seconds
# Time to Execute: 61.58 seconds
# Time to Execute: 53.66 seconds
# Time to Execute: 46.95 seconds
# Time to Execute: 56.21 seconds
# Time to Execute: 47.95 seconds
# Time to Execute: 59.48 seconds
# Time to Execute: 55.26 seconds
# Time to Execute: 59.29 seconds
# Time to Execute: 59.93 seconds
# Time to Execute: 56.93 seconds
# Time to Execute: 58.44 seconds
# Time to Execute: 58.64 seconds
# Time to Execute: 53.94 seconds
# Time to Execute: 54.64 seconds
# Time to Execute: 57.92 seconds
# Time to Execute: 58.27 seconds
# Time to Execute: 56.3 seconds
# Time to Execute: 52.23 seconds
# Time to Execute: 56.45 seconds
# Time to Execute: 56.79 seconds
# Time to Execute: 57.86 seconds
# Time to Execute: 50.23 seconds
# Time to Execute: 58.31 seconds
# Time to Execute: 50.38 seconds
# Time to Execute: 53.69 seconds
# Time to Execute: 54.63 seconds
# Time to Execute: 53.35 seconds
# Time to Execute: 54.15 seconds
# Time to Execute: 54.81 seconds
# Time to Execute: 56.76 seconds
# Time to Execute: 56.97 seconds
# Time to Execute: 56.35 seconds
# Time to Execute: 53.65 seconds
# Time to Execute: 48.97 seconds
# Time to Execute: 53.16 seconds
# Time to Execute: 51.13 seconds
# Time to Execute: 51.82 seconds
# Time to Execute: 53.25 seconds
# Time to Execute: 51.74 seconds
# Time to Execute: 53.69 seconds
# Time to Execute: 57.37 seconds
# Time to Execute: 60.44 seconds
# Time to Execute: 56.94 seconds
# Time to Execute: 56.22 seconds
# Time to Execute: 56.18 seconds
# Time to Execute: 57.54 seconds
# Time to Execute: 53.2 seconds
# Time to Execute: 53.19 seconds
# Time to Execute: 52.08 seconds
# Time to Execute: 53.67 seconds
# Time to Execute: 52.49 seconds
# Time to Execute: 53.01 seconds
# Time to Execute: 54.0 seconds
# Time to Execute: 53.2 seconds
# Time to Execute: 50.75 seconds
# Time to Execute: 50.05 seconds
# Time to Execute: 57.84 seconds
# Time to Execute: 60.36 seconds
# Time to Execute: 55.42 seconds
# token():INFO:   Token refreshed
# Time to Execute: 58.23 seconds
# Time to Execute: 57.92 seconds
# Time to Execute: 57.22 seconds
# Time to Execute: 46.94 seconds
# Time to Execute: 38.34 seconds
# Time to Execute: 53.07 seconds
# Time to Execute: 57.85 seconds
# Time to Execute: 59.01 seconds
# Time to Execute: 52.81 seconds
# Time to Execute: 53.37 seconds
# Time to Execute: 55.02 seconds
# Time to Execute: 54.17 seconds
# Time to Execute: 56.39 seconds
# Time to Execute: 52.89 seconds
# Time to Execute: 50.5 seconds
# Time to Execute: 54.0 seconds
# Time to Execute: 57.32 seconds
# Time to Execute: 55.52 seconds
# Time to Execute: 57.16 seconds
# Time to Execute: 56.25 seconds
# Time to Execute: 54.65 seconds
# Time to Execute: 53.97 seconds
# Time to Execute: 53.26 seconds
# Time to Execute: 56.38 seconds
# Time to Execute: 51.24 seconds
# Time to Execute: 53.18 seconds
# Time to Execute: 52.2 seconds
# Time to Execute: 54.45 seconds
# Time to Execute: 52.42 seconds
# Time to Execute: 54.36 seconds
# Time to Execute: 55.91 seconds
# Time to Execute: 52.8 seconds
# Time to Execute: 54.3 seconds
# Time to Execute: 53.69 seconds
# Time to Execute: 52.57 seconds
# Time to Execute: 58.51 seconds
# Time to Execute: 53.92 seconds
# Time to Execute: 51.75 seconds
# Time to Execute: 54.28 seconds
# Time to Execute: 52.52 seconds
# Time to Execute: 55.17 seconds
# Time to Execute: 51.36 seconds
# Time to Execute: 53.43 seconds
# Time to Execute: 55.88 seconds
# Time to Execute: 54.53 seconds
# Time to Execute: 54.01 seconds
# Time to Execute: 52.85 seconds
# Time to Execute: 55.41 seconds
# Time to Execute: 55.32 seconds
# Time to Execute: 52.65 seconds
# Time to Execute: 54.06 seconds
# Time to Execute: 52.23 seconds
# Time to Execute: 51.54 seconds
# Time to Execute: 53.04 seconds
# Time to Execute: 57.59 seconds
# Time to Execute: 52.79 seconds
# Time to Execute: 54.34 seconds
# Time to Execute: 53.46 seconds
# Time to Execute: 56.67 seconds
# Time to Execute: 55.19 seconds
# Time to Execute: 54.45 seconds
# token():INFO:   Token refreshed
# Time to Execute: 55.18 seconds
# Time to Execute: 54.48 seconds
# Time to Execute: 57.69 seconds
# Time to Execute: 52.78 seconds
# Time to Execute: 54.07 seconds
# Time to Execute: 57.81 seconds
# Time to Execute: 55.44 seconds
# Time to Execute: 55.85 seconds
# Time to Execute: 53.27 seconds
# Time to Execute: 50.06 seconds
# Time to Execute: 51.8 seconds
# Time to Execute: 58.94 seconds
# Time to Execute: 54.76 seconds
# Time to Execute: 57.07 seconds
# Time to Execute: 55.83 seconds
# Time to Execute: 53.82 seconds
# Time to Execute: 53.64 seconds
# Time to Execute: 54.9 seconds
# Time to Execute: 50.15 seconds
# Time to Execute: 53.55 seconds
# Time to Execute: 54.36 seconds
# Time to Execute: 58.32 seconds
# Time to Execute: 53.38 seconds
# Time to Execute: 56.29 seconds
# Time to Execute: 52.17 seconds
# Time to Execute: 55.78 seconds
# Time to Execute: 51.83 seconds
# Time to Execute: 51.07 seconds
# Time to Execute: 51.41 seconds
# Time to Execute: 51.3 seconds
# Time to Execute: 51.06 seconds
# Time to Execute: 52.51 seconds
# Time to Execute: 50.23 seconds
# Time to Execute: 50.7 seconds
# Time to Execute: 56.67 seconds
# Time to Execute: 54.51 seconds
# Time to Execute: 55.39 seconds
# Time to Execute: 50.96 seconds
# Time to Execute: 54.17 seconds
# Time to Execute: 52.03 seconds
# Time to Execute: 50.19 seconds
# Time to Execute: 52.96 seconds
# Time to Execute: 51.91 seconds
# Time to Execute: 53.99 seconds
# Time to Execute: 53.56 seconds
# Time to Execute: 54.85 seconds
# Time to Execute: 54.71 seconds
# Time to Execute: 51.98 seconds
# Time to Execute: 55.33 seconds
# Time to Execute: 54.47 seconds
# Time to Execute: 53.79 seconds
# Time to Execute: 50.08 seconds
# Time to Execute: 52.09 seconds
# Time to Execute: 52.76 seconds
# Time to Execute: 51.86 seconds
# Time to Execute: 49.46 seconds
# Time to Execute: 53.64 seconds
# Time to Execute: 54.44 seconds
# Time to Execute: 55.42 seconds
# Time to Execute: 51.97 seconds
# Time to Execute: 52.2 seconds
# Time to Execute: 50.91 seconds
# Time to Execute: 52.29 seconds
# Time to Execute: 52.71 seconds
# Time to Execute: 50.49 seconds
# token():INFO:   Token refreshed
# Time to Execute: 55.43 seconds
# Time to Execute: 39.81 seconds
# Time to Execute: 36.1 seconds
# Time to Execute: 56.38 seconds
# Time to Execute: 56.47 seconds
# Time to Execute: 55.92 seconds
# Time to Execute: 50.8 seconds
# Time to Execute: 54.82 seconds
# Time to Execute: 56.92 seconds
# Time to Execute: 55.96 seconds
# Time to Execute: 55.61 seconds
# Time to Execute: 49.85 seconds
# Time to Execute: 55.93 seconds
# Time to Execute: 56.84 seconds
# Time to Execute: 52.56 seconds
# Time to Execute: 57.55 seconds
# Time to Execute: 57.38 seconds
# Time to Execute: 55.35 seconds
# Time to Execute: 54.09 seconds
# Time to Execute: 57.23 seconds
# Time to Execute: 55.59 seconds
# Time to Execute: 55.77 seconds
# Time to Execute: 56.67 seconds
# Time to Execute: 55.4 seconds
# Time to Execute: 54.8 seconds
# Time to Execute: 57.62 seconds
# Time to Execute: 55.42 seconds
# Time to Execute: 55.34 seconds
# Time to Execute: 55.78 seconds
# Time to Execute: 56.95 seconds
# Time to Execute: 54.74 seconds
# Time to Execute: 57.27 seconds
# Time to Execute: 54.76 seconds
# Time to Execute: 56.37 seconds
# Time to Execute: 55.19 seconds
# Time to Execute: 57.97 seconds
# Time to Execute: 55.8 seconds
# Time to Execute: 57.65 seconds
# Time to Execute: 57.78 seconds
# Time to Execute: 55.12 seconds
# Time to Execute: 56.16 seconds
# Time to Execute: 51.95 seconds
# Time to Execute: 54.04 seconds
# Time to Execute: 57.42 seconds
# Time to Execute: 55.24 seconds
# Time to Execute: 56.66 seconds
# Time to Execute: 60.43 seconds
# Time to Execute: 58.61 seconds
# Time to Execute: 57.76 seconds
# Time to Execute: 56.66 seconds
# Time to Execute: 52.94 seconds
# Time to Execute: 57.83 seconds
# Time to Execute: 57.03 seconds
# Time to Execute: 56.01 seconds
# Time to Execute: 54.48 seconds
# Time to Execute: 53.23 seconds
# Time to Execute: 57.46 seconds
# Time to Execute: 58.78 seconds
# Time to Execute: 57.97 seconds
# Time to Execute: 54.32 seconds
# Time to Execute: 53.6 seconds
# Time to Execute: 55.05 seconds
# token():INFO:   Token refreshed
# Time to Execute: 55.24 seconds
# Time to Execute: 58.49 seconds
# Time to Execute: 56.12 seconds
# Time to Execute: 57.26 seconds
# 79080

# %% [markdown]
# ### Test Data using Implicit Join
# Join Songs and Audio_Features Tables implicitly

# %%
test_track = display_time(session.query(Playlists, Audio_Features)
                          .filter(Playlists.track_uri==Audio_Features.track_uri)
                          .distinct()
                          .first)
# Out:
# Time to Execute: 0.03 seconds

# %%
test_track.Audio_Features.acousticness
# Out:
# 0.974

# %%
for tk in test_track.keys():
    print (tk)
    tk_dict = test_track.__getattribute__(tk).__dict__
    for k,v in tk_dict.items():
        
        print ("\t{}  :  {}".format(k,v))
# Out:
# Playlists
# 	_sa_instance_state  :  <sqlalchemy.orm.state.InstanceState object at 0x1a2a202dd0>
# 	pos  :  b'\x00\x00\x00\x00\x00\x00\x00\x00'
# 	id  :  1
# 	track_uri  :  spotify:track:2d7LPtieXdIYzf7yHPooWd
# 	track_name  :  Chasing Cars
# 	duration_ms  :  b'\x84\xb3\x03\x00\x00\x00\x00\x00'
# 	playlist_id  :  1
# 	artist_name  :  Sleeping At Last
# 	artist_uri  :  spotify:artist:0MeLMJJcouYXCymQSHPn8g
# 	album_uri  :  spotify:album:0UIIvTTWNB3gRQWFoxoEDh
# 	album_name  :  Covers, Vol. 2
# Audio_Features
# 	_sa_instance_state  :  <sqlalchemy.orm.state.InstanceState object at 0x1a2a202e50>
# 	danceability  :  0.467
# 	key  :  11
# 	mode  :  1
# 	acousticness  :  0.974
# 	liveness  :  0.0816
# 	tempo  :  108.13
# 	duration_ms  :  242564
# 	loudness  :  -9.649
# 	energy  :  0.157
# 	track_uri  :  spotify:track:2d7LPtieXdIYzf7yHPooWd
# 	speechiness  :  0.0336
# 	instrumentalness  :  1.46e-06
# 	valence  :  0.277
# 	time_signature  :  4

# %%
for tk in test_track.keys():
    print (tk)
    tk_dict = test_track.__getattribute__(tk).__dict__
    for k,v in tk_dict.items():
        print ("\t{}  :  {}".format(k,type(v)))
# Out:
# Playlists
# 	_sa_instance_state  :  <class 'sqlalchemy.orm.state.InstanceState'>
# 	pos  :  <class 'bytes'>
# 	id  :  <class 'int'>
# 	track_uri  :  <class 'str'>
# 	track_name  :  <class 'str'>
# 	duration_ms  :  <class 'bytes'>
# 	playlist_id  :  <class 'int'>
# 	artist_name  :  <class 'str'>
# 	artist_uri  :  <class 'str'>
# 	album_uri  :  <class 'str'>
# 	album_name  :  <class 'str'>
# Audio_Features
# 	_sa_instance_state  :  <class 'sqlalchemy.orm.state.InstanceState'>
# 	danceability  :  <class 'float'>
# 	key  :  <class 'int'>
# 	mode  :  <class 'int'>
# 	acousticness  :  <class 'float'>
# 	liveness  :  <class 'float'>
# 	tempo  :  <class 'float'>
# 	duration_ms  :  <class 'int'>
# 	loudness  :  <class 'float'>
# 	energy  :  <class 'float'>
# 	track_uri  :  <class 'str'>
# 	speechiness  :  <class 'float'>
# 	instrumentalness  :  <class 'float'>
# 	valence  :  <class 'float'>
# 	time_signature  :  <class 'int'>

# %% [markdown]
# ### Playlist 'position' and 'duration' fields are binary for some reason.
# The following will update the db records to be integer values

# %%
int.from_bytes(test_track.Playlists.pos, byteorder='little')
# Out:
# 0

# %%
byte_track = display_time(session.query(Playlists)
                          .filter(Playlists.track_name=="Photograph")
                          .distinct()
                          .first)
# Out:
# Time to Execute: 0.01 seconds

# %%
int.from_bytes(byte_track.pos, byteorder='little')
# Out:
# 11

# %%
int.from_bytes(byte_track.duration_ms, byteorder='little')
# Out:
# 258986

# %%
# Iterate through Playlists
# replace the value in postion with the int value 
# replace duration with the int value
# only do replacements where the value is of type 'byte'

# %%
def get_batch(fr_entry:int, to_entry:int, TableName):
    batch = session.query(TableName).filter(and_(TableName.id>=fr_entry, 
                                                 TableName.id<to_entry)).all()
    return batch

# %%
batch_size     =    1
start_record   = 35639100
stop_record    = 35639200
length         = stop_record - start_record #session.query(Playlists).count()-start
batches        = int(length/batch_size) # int((length-start)/batch_size)

# %%
batch_size, start_record, stop_record, length, batches
# Out:
# (1, 35639100, 35639200, 100, 100)

# %%
length, batches
# Out:
# (100, 100)

# %%
# convert byte value in pos and duration field to integer
exception_ranges = []

for b in tqdm(range(batches)):
    
    start = start_record + (b*batch_size)
    end   = start_record + (b*batch_size) + batch_size
    if end > stop_record+1:
        end = stop_record+1
        
    for e in get_batch(start,end,Playlists):
        
        commit = False
        if type(e.pos) == bytes:
            int_posval = int.from_bytes(e.pos, byteorder='little')
            e.pos = int_posval
            commit = True

        if type(e.duration_ms) == bytes:
            int_durval = int.from_bytes(e.duration_ms, byteorder='little')
            e.duration_ms = int_durval
            commit = True
    
    # only do a commit if we changed something
    if commit:
        try:
            session.commit()
        except Exception as e:
            session.rollback()
            print("Caught Exception: {}".format (e))
            print("\t\tIn record range: {} - {}".format(start,end))
            exception_ranges.append((start,end))
            
    
    
        
if len(exception_ranges)>0:
    print("Review Exception Ranges:")
    for e in exception_ranges:
        print ("from: {}  to: {}".format(e[0], e[1]))
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %% [markdown]
# ### Found that record 35639172 had an incorrect duration_ms value
# manually correcting it

# %%
b = get_batch(35639173, 35639174, Playlists)

# %%
int.from_bytes(b[0].pos, byteorder='little')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-cfc8dc268af3> in <module>
# ----> 1 int.from_bytes(b[0].pos, byteorder='little')
#
# TypeError: cannot convert 'int' object to bytes

# %%
b[0].pos
# Out:
# 29

# %%
int.from_bytes(b[0].duration_ms, byteorder='little')/1000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-16fef8b527b9> in <module>
# ----> 1 int.from_bytes(b[0].duration_ms, byteorder='little')/1000
#
# TypeError: cannot convert 'int' object to bytes

# %%
b[0].duration_ms
# Out:
# 60132

# %%
b[0].track_uri
# Out:
# 'spotify:track:6lrtPENGGkx8InNienHt5E'

# %%
get_spotify_data(b[0].track_uri, 'duration_ms')
# Out:
# 60132

# %%
b[0].duration_ms = 1947

# %%
session.commit()
