# %% [markdown]
# ### Spotify EDA
# #### Load Audio Features

# %% [markdown]
# Get audio features from Spotify for every song in the database.
# Create a new table called "Features" where each record is a song.
# Primary key is the Spotify Track URI.

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os
import sys
import json
import seaborn as sns

from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Table, Column, Integer, String, Float, MetaData, and_, or_
from sqlalchemy import create_engine
import sqlite3
from sqlalchemy.orm import sessionmaker

sys.path.append('../')
from spotify_api import get_spotify_data, get_tracks, get_artists, get_audiofeatures
from spotify_database import get_session, display_time

#TEMP
from spotify_api import parse_spotify_url, token, TokenAuth
import requests

from urllib.parse import urlencode

# %matplotlib inline

# %%
# !pip install ipywidgets 
# !jupyter nbextension enable --py widgetsnbextension
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager

# %%capture
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %% [markdown]
# ### Establish DataBase Connection

# %%
db_path = '../data/spotify_songs.db'

# Get sesion
session = get_session(db_path)
engine = create_engine('sqlite:///' + db_path)

# Get Songs class
Playlists = getattr(get_session, "Playlists")
Tracks = getattr(get_session, "Tracks")
Artists = getattr(get_session, "Artists")

# %% [markdown]
# ### Establish Spotify API Connection

# %%
# Get URI for Artist, Track and Album for a song
rv = display_time(session.query(Playlists.track_name, 
                                Playlists.track_uri,
                                Playlists.artist_uri,
                                Playlists.album_uri).filter(Playlists.track_name=="Who Says").distinct().first)
# Out:
# Time to Execute: 0.0 seconds

# %%
get_spotify_data(db_uri=rv.artist_uri, key='genres')
# Out:
# Setting credentials
# token():INFO:   Getting initial token
# token():INFO:   Token refreshed
# ['neo mellow', 'pop', 'pop rock', 'singer-songwriter']

# %%
# Create DB and Table if they don't exist

# engine = create_engine('sqlite:///' + db_path)
# connection = engine.connect() #creates db if it doesn't exist
# meta = MetaData()

# songs = Table(
#                 'songs', meta,
#                 Column('id', Integer, primary_key = True),
#                 Column('playlist_id', Integer),
#                 Column('pos', Integer), 
#                 Column('artist_name', String), 
#                 Column('track_uri', String),
#                 Column('artist_uri', String), 
#                 Column('track_name', String),
#                 Column('album_uri', String), 
#                 Column('duration_ms', String), 
#                 Column('album_name', String)
# )

# features = Table(
#                 'audio_features', meta,
#                 Column('track_uri', String, primary_key = True),
#                 Column('danceability', Float),
#                 Column('energy', Float),
#                 Column('key', Integer),
#                 Column('loudness', Float),
#                 Column('mode', Integer),
#                 Column('speechiness', Float),
#                 Column('acousticness', Float),
#                 Column('instrumentalness', Float),
#                 Column('liveness', Float),
#                 Column('valence', Float),
#                 Column('tempo', Float),
#                 Column('duration_ms', Integer),
#                 Column('time_signature', Integer)
# )

# playlists = Table(
#                 'playlists', meta,
#                 Column('id', Integer, primary_key = True),
#                 Column('playlist_id', Integer),
#                 Column('pos', Integer), 
#                 Column('artist_name', String), 
#                 Column('track_uri', String, ForeignKey(audio_features.track_uri)),
#                 Column('artist_uri', String), 
#                 Column('track_name', String),
#                 Column('album_uri', String), 
#                 Column('duration_ms', String), 
#                 Column('album_name', String)
# )

# meta.create_all(engine)

# %%
def build_track_string(uri_list:list) -> str:
    rv_str = ''
    
    for u in uri_list:
        t_type, t_id = parse_spotify_url(u)
        if t_type != "track":
            print("ERR: Only 'track'-type uri's have features: {}".format(u))
            return False
        
        if rv_str == '':
            rv_str += t_id
        else:
            rv_str += ',' + t_id
            
    return rv_str

# %%
# get audiofeatures
from time import sleep
def get_audiofeatures(uri_list:list) -> list:

    r_dict = {'ids': build_track_string(uri_list)}
        
    # build spotify url from db uri
    spotify_url = "https://api.spotify.com/v1/audio-features/"

    token()  # ensure token is valid
    response = requests.get(spotify_url, 
                            auth=TokenAuth('Bearer ' + token.token),
                            params=r_dict)
    
    if response.status_code == 429: # too many requests
        retry_value = response.headers.get('Retry-After')
        print("API limit.  Waiting {} seconds".format(retry_value))
        for s in tqdm(range(retry_value+1)):
#             print("{}".format(retry_value-s), end='\r')
            sleep(1)
            
        # resend request
        token()  # ensure token is valid
        response = requests.get(spotify_url, 
                            auth=TokenAuth('Bearer ' + token.token),
                            params=r_dict)
                
    if response.status_code != 200:
        print("ERR: Unable to access Spotify data:  ERR:{}".format(response.status_code, url))
        return False
    
    return response.json().get('audio_features')

# %%
def load_features(audio_features):
    Session = sessionmaker(bind = engine)
    session = Session()
    
    for f in audio_features:

        session.add(Audio_Features( track_uri           = f.get('uri'),
                                    danceability        = f.get('danceability'),
                                    energy              = f.get('energy'),
                                    key                 = f.get('key'),
                                    loudness            = f.get('loudness'),
                                    mode                = f.get('mode'),
                                    speechiness         = f.get('speechiness'),
                                    acousticness        = f.get('acousticness'),
                                    instrumentalness    = f.get('instrumentalness'),
                                    liveness            = f.get('liveness'),
                                    valence             = f.get('valence'),
                                    tempo               = f.get('tempo'),
                                    duration_ms         = f.get('duration_ms'),
                                    time_signature      = f.get('time_signature')
                                  ) 
                   )

    session.commit()
    return len(audio_features)

# %%
def load_all(all_tracks, blk_size:int=100):
    """
    Loads all track audio features into db.
    Spotify only allows 100 tracks to be queried at once.
    """

    length = len(all_tracks)
    if length==0:
        print("No records to load")
        return False
    
    start = 0
    for end in tqdm(range(blk_size,length+blk_size,blk_size)):
        if end>length:
            end=length

        # do query
        af = get_audiofeatures(all_tracks[start:end])
        start = end

        # do load
        load_features(af)

# %% [markdown]
# ### Load Audio Features
#
# First see what may already be loaded and only load items in the Songs DB that aren't already in the Audio_Features DB

# %%
# get all unique tracks from playlists
all_tracks = display_time(session.query(Playlists.track_uri).distinct().all)
all_tracks = [t.track_uri for t in all_tracks]

# make sure we aren't loading something already loaded
loaded_tracks = display_time(session.query(Audio_Features.track_uri).all)
loaded_tracks = [t.track_uri for t in loaded_tracks]

missing_tracks = list(set(all_tracks) - set(loaded_tracks))

len(missing_tracks)
# Out:
# Time to Execute: 189.36 seconds

# %%
# WARNING!!!  Loads all values into DB
# Initial load will take several hours - 2 hrs est 
# load_all(missing_tracks, blk_size=10 )

# %%
# Out:
# Time to Execute: 96.4 seconds

# %%
# Out:
# 0

# %% [markdown]
# ### Test Data using Implicit Join
# Join Songs and Audio_Features Tables implicitly

# %%
test_track = display_time(session.query(Playlists, Audio_Features)
                          .filter(Playlists.track_uri==Audio_Features.track_uri)
                          .distinct()
                          .first)
# Out:
# Time to Execute: 0.07 seconds

# %%
test_track.Audio_Features.acousticness
# Out:
# 0.974

# %%
for tk in test_track.keys():
    print (tk)
    tk_dict = test_track.__getattribute__(tk).__dict__
    for k,v in tk_dict.items():
        print ("\t{}  :  {}".format(k,v))
# Out:
# Playlists
# 	_sa_instance_state  :  <sqlalchemy.orm.state.InstanceState object at 0x1a21921890>
# 	pos  :  0
# 	id  :  1
# 	track_uri  :  spotify:track:2d7LPtieXdIYzf7yHPooWd
# 	artist_uri  :  spotify:artist:0MeLMJJcouYXCymQSHPn8g
# 	album_uri  :  spotify:album:0UIIvTTWNB3gRQWFoxoEDh
# 	album_name  :  Covers, Vol. 2
# 	artist_name  :  Sleeping At Last
# 	playlist_id  :  1
# 	track_name  :  Chasing Cars
# 	duration_ms  :  242564
# Audio_Features
# 	_sa_instance_state  :  <sqlalchemy.orm.state.InstanceState object at 0x1a219218d0>
# 	danceability  :  0.467
# 	key  :  11
# 	loudness  :  -9.649
# 	speechiness  :  0.0336
# 	instrumentalness  :  1.46e-06
# 	valence  :  0.277
# 	duration_ms  :  242564
# 	track_uri  :  spotify:track:2d7LPtieXdIYzf7yHPooWd
# 	energy  :  0.157
# 	mode  :  1
# 	acousticness  :  0.974
# 	liveness  :  0.0816
# 	tempo  :  108.13
# 	time_signature  :  4

# %% [markdown]
# ### Add artist_popularity and track_popularity
# We will add values from artist and track popularity from values retrieved from the
# Sportify API.  Since this may change, we will want to make this in such a way that a normal database maintenace can be run to include this task.

# %%
# artist popularity will come from the Artists table
# track popularity comes from the Spotify database

# %%
test_track = display_time(session.query(Audio_Features).first)
test_track.track_uri
# Out:
# Time to Execute: 0.0 seconds
# 'spotify:track:2d7LPtieXdIYzf7yHPooWd'

# %%
test_track_popularity = get_spotify_data(test_track.track_uri, "popularity")
test_track_popularity
# Out:
# 65

# %%
test_track_artist = get_spotify_data(test_track.track_uri, "artists")
test_track_artist[0].get('uri')
# Out:
# 'spotify:artist:0MeLMJJcouYXCymQSHPn8g'

# %%
artist_popularity = display_time(session.query(Artists.artist_popularity).filter(Artists.artist_uri==test_track_artist[0].get('uri')).first)
artist_popularity[0]
# Out:
# Time to Execute: 0.0 seconds
# 74

# %%
test_track.track_popularity = test_track_popularity
test_track.artist_popularity = artist_popularity[0]
session.commit()

# %%
# def build_id_string(uri_list:list) -> str:
#     rv_str = ''
    
#     for u in uri_list:
#         t_type, t_id = parse_spotify_url(u)
        
#         if rv_str == '':
#             rv_str += t_id
#         else:
#             rv_str += ',' + t_id
            
#     return rv_str

# %%
build_id_string(['spotify:track:0y4TKcc7p2H6P0GJlt01EI'])
# Out:
# '0y4TKcc7p2H6P0GJlt01EI'

# %%
# get audiofeatures
# from time import sleep
# def get_tracks(uri_list:list) -> list:

#     r_dict = {'ids': build_id_string(uri_list)}
        
#     # build spotify url from db uri
#     spotify_url = "https://api.spotify.com/v1/tracks/"

#     token()  # ensure token is valid
#     response = requests.get(spotify_url, 
#                             auth=TokenAuth('Bearer ' + token.token),
#                             params=r_dict)
    
#     if response.status_code == 429: # too many requests
#         retry_value = response.headers.get('Retry-After')
#         print("API limit.  Waiting {} seconds".format(retry_value))
#         for s in tqdm(range(retry_value+1)):
#             sleep(1)
            
#         # resend request
#         token()  # ensure token is valid
#         response = requests.get(spotify_url, 
#                             auth=TokenAuth('Bearer ' + token.token),
#                             params=r_dict)
                
#     if response.status_code != 200:
#         print("ERR: Unable to access Spotify data:  ERR:{}".format(response.status_code, url))
#         return False
    
#     return response.json().get('tracks')

# %%
# get artists
# from time import sleep
# def get_artists(artist_uri_list:list) -> list:
    
#     r_dict = {'ids': build_id_string(artist_uri_list)}
        
#     # build spotify url from db uri
#     spotify_url = "https://api.spotify.com/v1/artists/"

#     token()  # ensure token is valid
#     response = requests.get(spotify_url, 
#                             auth=TokenAuth('Bearer ' + token.token),
#                             params=r_dict)
    
#     if response.status_code == 429: # too many requests
#         retry_value = response.headers.get('Retry-After')
#         print("API limit.  Waiting {} seconds".format(retry_value))
#         for s in tqdm(range(retry_value+1)):
#             sleep(1)
            
#         # resend request
#         token()  # ensure token is valid
#         response = requests.get(spotify_url,
#                                 auth=TokenAuth('Bearer ' + token.token),
#                                 params=r_dict)
                
#     if response.status_code != 200:
#         print("ERR: Unable to access Spotify data:  ERR:{}".format(response.status_code, url))
#         return False
    
#     return response.json().get('artists')

# %%
def load_artists(artists_uri_list):
    
    if type(artists_uri_list) != list:
        print("load_artsist() needs a list. {} type provided.".format(type(artists_uri_list)))
        return 0
    
    Session = sessionmaker(bind = engine)
    session = Session()
    
    artists = get_artists(artists_uri_list)
    
    for a in artists:

        session.add(Artists( artist_uri          = a.get('uri'),
                             followers           = a.get('followers').get('total'),
                             genres              = ",".join(a.get('genres')),
                             artist_name         = a.get('name'),
                             artist_popularity   = a.get('popularity')
                           )
                   )

    try:
        session.commit()
    except Exception as e:
        print(e)
        session.rollback()
        
        # commit individually
        for i, a in enumerate(artists):
            session.add(Artists( artist_uri          = a.get('uri'),
                                 followers           = a.get('followers').get('total'),
                                 genres              = ",".join(a.get('genres')),
                                 artist_name         = a.get('name'),
                                 artist_popularity   = a.get('popularity')
                               )
                       )
            try:
                session.commit()
            except Exception as e:
                print("DUPLICATE {}: {} - {}".format(i, a.get('uri'), a.get('name') ))
                session.rollback()
        
    return len(artists)

# %%
# Check that artists exist in Artist table - load, if they don't
# returns the artist db entries
def get_db_artists(artist_uri_list) -> list:
    """
    Checks that a list of artists exists in the Artists
    table and will load any that don't exist
    """
    session = get_session(db_path)
    
    db_artist_list = []
    for a in artist_uri_list:
        db_artist = session.query(Artists).filter(Artists.artist_uri==a).first()
        if db_artist == None:
            # artist is missing - load artist
            print("Loading missing artist: {}".format(a))
            load_artists([a])
            # now get the db isting of the artist
            db_artist = session.query(Artists).filter(Artists.artist_uri==a).first()
        db_artist_list.append(db_artist)
        
    return db_artist_list

# %%
def update_table_track_popularity(batch_size:int=50):
    # iterate over track table 50 tracks at a time:
    
    
    # get all artist popularities
    session_a = get_session(db_path)
    artist_popularity = display_time(session_a.query(Artists.artist_uri, Artists.artist_popularity).all)
    session_a.close()
    df_artist_popularity = pd.DataFrame(artist_popularity)
    
    # get all song records
    session_b = get_session(db_path)
    records = display_time(session_b.query(Audio_Features).all)
    
    
    batch_num = 0
    ttl_len = len(records)
    missing_artists = []
    
    pbar = tqdm(total = ttl_len)
    
    while batch_num==0 or end_record != ttl_len:
        
        # determine start and end records
        start_record = batch_num*batch_size
        end_record = batch_num*batch_size + batch_size
        if end_record > ttl_len:
            end_record = ttl_len
        pbar.update(end_record)
        batch_num += 1
        
        #get first batch 
        record_batch = records[start_record:end_record]
        
        # get spotify track popularity
        track_uris = [t.track_uri for t in record_batch] #get uris for batch
        batch_tracks = get_tracks(track_uris)
        
        if len(batch_tracks)==0:
            print("Got no tracks from Spotify: {} {}".format(start_record, end_record))
            continue
            
        # remove any None tracks
        poplist = []
        for i, bt in enumerate(batch_tracks):
            if bt==None:
                print("Spotify returned None for track uri: {}".format(track_uris[i]))
                poplist.append(i)
        if len(poplist)>0:
            for p in poplist:
                record_batch.pop(p)
                batch_tracks.pop(p)
                
        
        # get list of artists from the tracks
        batch_artist_uris = []
        for i, track in enumerate(batch_tracks):
            track_artists = track.get('artists')
            if len(track_artists) > 1: # many artists - use first one
                batch_artist_uris.append(track_artists[0].get('uri'))
            elif len(track_artists) == 1: # exactly one artist
                batch_artist_uris.append(track_artists[0].get('uri'))
            else: # no artist
                batch_artist_uris.append(0)
        
        # iterate over batch items and update popularity
        for i, record in enumerate(record_batch):
            record.track_popularity  =  batch_tracks[i].get('popularity')
            if batch_artist_uris[i] not in df_artist_popularity.artist_uri.values:
                # not in table - create new record
                print("Artist not in Artist Table: {}".format(batch_artist_uris[i]))
                db_artist = get_db_artists([batch_artist_uris[i]])
                a_popularity = db_artist[0].artist_popularity
            else:
                # in table - use table
                a_popularity = df_artist_popularity[df_artist_popularity.artist_uri==batch_artist_uris[i]]['artist_popularity'].values[0]
                
            record.artist_popularity = int(a_popularity)
        
        session_b.commit()
        
    
    session_b.close()
    
    print("Process updated successfully. {} records updated".format(end_record))
    return True

# %%
missing_artists = update_table_track_popularity()
# Out:
# Time to Execute: 1.58 seconds
# Time to Execute: 70.41 seconds
# HBox(children=(IntProgress(value=0, max=2262181), HTML(value='')))
# Artist not in Artist Table: spotify:artist:3lZC3GwPPnP3iNlGeefXmU
# Loading missing artist: spotify:artist:3lZC3GwPPnP3iNlGeefXmU
# Artist not in Artist Table: spotify:artist:1MRUJTfySLy76mbSbNzv3m
# Loading missing artist: spotify:artist:1MRUJTfySLy76mbSbNzv3m
# Artist not in Artist Table: spotify:artist:2vXVp4yfl4bYVu9yUlInAw
# Loading missing artist: spotify:artist:2vXVp4yfl4bYVu9yUlInAw
# Artist not in Artist Table: spotify:artist:6vl7a7WifJu5SzSlhD4TYK
# Loading missing artist: spotify:artist:6vl7a7WifJu5SzSlhD4TYK
# Artist not in Artist Table: spotify:artist:1UkYB1n44YzBCtMaKde48Y
# Loading missing artist: spotify:artist:1UkYB1n44YzBCtMaKde48Y
# Artist not in Artist Table: spotify:artist:6p8HxXTeHr4099KlceJfX8
# Loading missing artist: spotify:artist:6p8HxXTeHr4099KlceJfX8
# Artist not in Artist Table: spotify:artist:7Bd76GC9TGpRm9Oh7LH7Kx
# Loading missing artist: spotify:artist:7Bd76GC9TGpRm9Oh7LH7Kx
# Artist not in Artist Table: spotify:artist:6BEeRmjcJ97XFPCJnL1hIj
# Loading missing artist: spotify:artist:6BEeRmjcJ97XFPCJnL1hIj
# Artist not in Artist Table: spotify:artist:1V31kaJ86tFJxaj4xlHQtC
# Loading missing artist: spotify:artist:1V31kaJ86tFJxaj4xlHQtC
# Artist not in Artist Table: spotify:artist:0ML7PFv211gjHmmSsIibOI
# Loading missing artist: spotify:artist:0ML7PFv211gjHmmSsIibOI
# Artist not in Artist Table: spotify:artist:4thfsgmluRHQutMgPrr8yq
# Loading missing artist: spotify:artist:4thfsgmluRHQutMgPrr8yq
# Artist not in Artist Table: spotify:artist:3WZhOX9lbeUUagirRi1RQW
# Loading missing artist: spotify:artist:3WZhOX9lbeUUagirRi1RQW
# Artist not in Artist Table: spotify:artist:0p3T2qoQCU24EIQ1FCGvky
# Loading missing artist: spotify:artist:0p3T2qoQCU24EIQ1FCGvky
# Artist not in Artist Table: spotify:artist:7rTX3vkJGGXk4paPJtGf0t
# Loading missing artist: spotify:artist:7rTX3vkJGGXk4paPJtGf0t
# Artist not in Artist Table: spotify:artist:14WrzELIM8pzWf826L3QC6
# Loading missing artist: spotify:artist:14WrzELIM8pzWf826L3QC6
# Artist not in Artist Table: spotify:artist:3J44LjCSFOFm2Ft11coMId
# Loading missing artist: spotify:artist:3J44LjCSFOFm2Ft11coMId
# Artist not in Artist Table: spotify:artist:5a7UbHO2NXSeqUH5WLCQi6
# Loading missing artist: spotify:artist:5a7UbHO2NXSeqUH5WLCQi6
# Artist not in Artist Table: spotify:artist:6yrovMYhgftVImYWt9uj06
# Loading missing artist: spotify:artist:6yrovMYhgftVImYWt9uj06
# Artist not in Artist Table: spotify:artist:14KZZk2V0Q6AYGtMwzgQur
# Loading missing artist: spotify:artist:14KZZk2V0Q6AYGtMwzgQur
# Artist not in Artist Table: spotify:artist:1M1rXUN2IL6icDsznzi7Ft
# Loading missing artist: spotify:artist:1M1rXUN2IL6icDsznzi7Ft
# Artist not in Artist Table: spotify:artist:1MzelWmQBbjVwITngDTscD
# Loading missing artist: spotify:artist:1MzelWmQBbjVwITngDTscD
# Artist not in Artist Table: spotify:artist:00YJFmTkMloy3dYPLExyRr
# Loading missing artist: spotify:artist:00YJFmTkMloy3dYPLExyRr
# Artist not in Artist Table: spotify:artist:4X0ZaZPlIU50BZIvOOvzfN
# Loading missing artist: spotify:artist:4X0ZaZPlIU50BZIvOOvzfN
# Artist not in Artist Table: spotify:artist:6dHeDHdhGXNzuG7hWjJM5A
# Loading missing artist: spotify:artist:6dHeDHdhGXNzuG7hWjJM5A
# Artist not in Artist Table: spotify:artist:1RfozqaXTEqoSB5OANn9yu
# Loading missing artist: spotify:artist:1RfozqaXTEqoSB5OANn9yu
# Artist not in Artist Table: spotify:artist:4gSrksboUZ0u6MSIgRJyBg
# Loading missing artist: spotify:artist:4gSrksboUZ0u6MSIgRJyBg
# Artist not in Artist Table: spotify:artist:1evtVBE3Xj2MzWAjOiNDcS
# Loading missing artist: spotify:artist:1evtVBE3Xj2MzWAjOiNDcS
# Artist not in Artist Table: spotify:artist:6vr4JjO47NO51S85J7OFiz
# Loading missing artist: spotify:artist:6vr4JjO47NO51S85J7OFiz
# Artist not in Artist Table: spotify:artist:0C1QbD4Gf7UZtWxPgo0AhN
# Loading missing artist: spotify:artist:0C1QbD4Gf7UZtWxPgo0AhN
# Artist not in Artist Table: spotify:artist:2DgN1RDrl5WZlUoSkjfFIR
# Loading missing artist: spotify:artist:2DgN1RDrl5WZlUoSkjfFIR
# Artist not in Artist Table: spotify:artist:3PNqkJIqpFQVOJ4MxYzc3n
# Loading missing artist: spotify:artist:3PNqkJIqpFQVOJ4MxYzc3n
# Artist not in Artist Table: spotify:artist:1Bi4XLEzsbw5ilxli07KYS
# Loading missing artist: spotify:artist:1Bi4XLEzsbw5ilxli07KYS
# Artist not in Artist Table: spotify:artist:2sVthFU8L5tg2wBK7y2u9l
# Loading missing artist: spotify:artist:2sVthFU8L5tg2wBK7y2u9l
# Artist not in Artist Table: spotify:artist:76AGnfKhsXgTiG6DJF4qxT
# Loading missing artist: spotify:artist:76AGnfKhsXgTiG6DJF4qxT
# Artist not in Artist Table: spotify:artist:68qRklewuFhi50agtf76un
# Loading missing artist: spotify:artist:68qRklewuFhi50agtf76un
# Artist not in Artist Table: spotify:artist:7BouKelHMxy42RJSMzkE0w
# Loading missing artist: spotify:artist:7BouKelHMxy42RJSMzkE0w
# Artist not in Artist Table: spotify:artist:7pxQXgXfp5gNTu6SeITHHY
# Loading missing artist: spotify:artist:7pxQXgXfp5gNTu6SeITHHY
# Artist not in Artist Table: spotify:artist:5G0g2q3vAaYIo4UfKMs3xB
# Loading missing artist: spotify:artist:5G0g2q3vAaYIo4UfKMs3xB
# Artist not in Artist Table: spotify:artist:75myVgZbKQkWpyHAlLUCmG
# Loading missing artist: spotify:artist:75myVgZbKQkWpyHAlLUCmG
# Artist not in Artist Table: spotify:artist:4IrNu2S9aBfbc9g5ERv9Vj
# Loading missing artist: spotify:artist:4IrNu2S9aBfbc9g5ERv9Vj
# Artist not in Artist Table: spotify:artist:38h6C9vccCIeDWYgNwo2tT
# Loading missing artist: spotify:artist:38h6C9vccCIeDWYgNwo2tT
# Artist not in Artist Table: spotify:artist:7Cjzvrb5lYaknnsPgZXgtl
# Loading missing artist: spotify:artist:7Cjzvrb5lYaknnsPgZXgtl
# Artist not in Artist Table: spotify:artist:5C0VpslPBd7fgYkuRGLdKJ
# Loading missing artist: spotify:artist:5C0VpslPBd7fgYkuRGLdKJ
# Artist not in Artist Table: spotify:artist:4sDnhfo72kJfMrLlcJwq6h
# Loading missing artist: spotify:artist:4sDnhfo72kJfMrLlcJwq6h
# Artist not in Artist Table: spotify:artist:2eQPDhVoSa5aeWROa5wfxZ
# Loading missing artist: spotify:artist:2eQPDhVoSa5aeWROa5wfxZ
# Artist not in Artist Table: spotify:artist:3d561LopikF6xENX46xIRT
# Loading missing artist: spotify:artist:3d561LopikF6xENX46xIRT
# Artist not in Artist Table: spotify:artist:0LWdHDPmZxRX7xLBBbyJWv
# Loading missing artist: spotify:artist:0LWdHDPmZxRX7xLBBbyJWv
# Artist not in Artist Table: spotify:artist:7u7ygOqRk4PfdgFaCNnyI3
# Loading missing artist: spotify:artist:7u7ygOqRk4PfdgFaCNnyI3
# Artist not in Artist Table: spotify:artist:7B6lMJB2IverbfIiEjIuu4
# Loading missing artist: spotify:artist:7B6lMJB2IverbfIiEjIuu4
# Artist not in Artist Table: spotify:artist:2eQPDhVoSa5aeWROa5wfxZ
# Artist not in Artist Table: spotify:artist:3B9OdGoXe2DUwoNJq3N9qY
# Loading missing artist: spotify:artist:3B9OdGoXe2DUwoNJq3N9qY
# Artist not in Artist Table: spotify:artist:53vKHY402CWQ7zS39i0CyW
# Loading missing artist: spotify:artist:53vKHY402CWQ7zS39i0CyW
# Artist not in Artist Table: spotify:artist:4z8u6rvYBxiXNcG3WQJhRR
# Loading missing artist: spotify:artist:4z8u6rvYBxiXNcG3WQJhRR
# Artist not in Artist Table: spotify:artist:27oj5rEBbg45aly4DKL8G5
# Loading missing artist: spotify:artist:27oj5rEBbg45aly4DKL8G5
# Artist not in Artist Table: spotify:artist:1WvZLZsvdYAJbjDsJeLQXE
# Loading missing artist: spotify:artist:1WvZLZsvdYAJbjDsJeLQXE
# Artist not in Artist Table: spotify:artist:2zTEKwbAhknhT8SQNasvUR
# Loading missing artist: spotify:artist:2zTEKwbAhknhT8SQNasvUR
# Artist not in Artist Table: spotify:artist:50I89CDuC7af1QPQbxIhq5
# Loading missing artist: spotify:artist:50I89CDuC7af1QPQbxIhq5
# Artist not in Artist Table: spotify:artist:6gUSvUp5J1k0pKJs183QmJ
# Loading missing artist: spotify:artist:6gUSvUp5J1k0pKJs183QmJ
# Artist not in Artist Table: spotify:artist:5eXcYFE6Bh2ALvm5rOrreB
# Loading missing artist: spotify:artist:5eXcYFE6Bh2ALvm5rOrreB
# Artist not in Artist Table: spotify:artist:2tlQNGpRvHLBEGGqfXmKPH
# Loading missing artist: spotify:artist:2tlQNGpRvHLBEGGqfXmKPH
# Artist not in Artist Table: spotify:artist:1f8kkEZiAsfbMRCIkjLbLc
# Loading missing artist: spotify:artist:1f8kkEZiAsfbMRCIkjLbLc
# Artist not in Artist Table: spotify:artist:6l7quaU13g2g9cBz8STEuq
# Loading missing artist: spotify:artist:6l7quaU13g2g9cBz8STEuq
# Artist not in Artist Table: spotify:artist:1zxY2WLsIRIJ1fwuSyPz7z
# Loading missing artist: spotify:artist:1zxY2WLsIRIJ1fwuSyPz7z
# Artist not in Artist Table: spotify:artist:7vgJnbva49FV9p5EkNlKq7
# Loading missing artist: spotify:artist:7vgJnbva49FV9p5EkNlKq7
# Artist not in Artist Table: spotify:artist:368UmHqvfoaAZH68k0EQyq
# Loading missing artist: spotify:artist:368UmHqvfoaAZH68k0EQyq
# Artist not in Artist Table: spotify:artist:6bY00PLfv1bngY6hDZsPFw
# Loading missing artist: spotify:artist:6bY00PLfv1bngY6hDZsPFw
# Artist not in Artist Table: spotify:artist:3BYuli0zAGgTeoH9m9kB1J
# Loading missing artist: spotify:artist:3BYuli0zAGgTeoH9m9kB1J
# Artist not in Artist Table: spotify:artist:6IEkVzhEdTVwx0sIPMA7Q9
# Loading missing artist: spotify:artist:6IEkVzhEdTVwx0sIPMA7Q9
# Artist not in Artist Table: spotify:artist:5Zo91kZcePj1rwAERjQVn8
# Loading missing artist: spotify:artist:5Zo91kZcePj1rwAERjQVn8
# Artist not in Artist Table: spotify:artist:72cTWq7xhaQ6SZ50IbvHGv
# Loading missing artist: spotify:artist:72cTWq7xhaQ6SZ50IbvHGv
# Spotify returned None for track uri: spotify:track:1pTy8JZSD7UTU5Xg4Cs8VX
# Artist not in Artist Table: spotify:artist:1kydV1RJaCH3wePowuxDhB
# Loading missing artist: spotify:artist:1kydV1RJaCH3wePowuxDhB
# Artist not in Artist Table: spotify:artist:06zS0fTnfMX9Bg3UTfKbD9
# Loading missing artist: spotify:artist:06zS0fTnfMX9Bg3UTfKbD9
# Artist not in Artist Table: spotify:artist:6oGu98dOZ0PcHUkSNwORsg
# Loading missing artist: spotify:artist:6oGu98dOZ0PcHUkSNwORsg
# Artist not in Artist Table: spotify:artist:7KGmbfnToVvudDYxmh4PY5
# Loading missing artist: spotify:artist:7KGmbfnToVvudDYxmh4PY5
# Artist not in Artist Table: spotify:artist:3B9OdGoXe2DUwoNJq3N9qY
# Artist not in Artist Table: spotify:artist:29UZPJ8UlkJPZBGw0SS8iR
# Loading missing artist: spotify:artist:29UZPJ8UlkJPZBGw0SS8iR
# Artist not in Artist Table: spotify:artist:23a7RRnIpe5rS97rEU0MzC
# Loading missing artist: spotify:artist:23a7RRnIpe5rS97rEU0MzC
# Artist not in Artist Table: spotify:artist:2JcB0D3GGG5BhIJDkdtXi7
# Loading missing artist: spotify:artist:2JcB0D3GGG5BhIJDkdtXi7
# Artist not in Artist Table: spotify:artist:21jIk1sXKLzlGlc0pg9UUY
# Loading missing artist: spotify:artist:21jIk1sXKLzlGlc0pg9UUY
# Artist not in Artist Table: spotify:artist:3gRYSBYE2fgE6v5VbUQwMw
# Loading missing artist: spotify:artist:3gRYSBYE2fgE6v5VbUQwMw
# Artist not in Artist Table: spotify:artist:4vtbitmYOhHCMWk5UddrgY
# Loading missing artist: spotify:artist:4vtbitmYOhHCMWk5UddrgY
# Artist not in Artist Table: spotify:artist:2ZkTNedGwwbYfGZkbPfsN5
# Loading missing artist: spotify:artist:2ZkTNedGwwbYfGZkbPfsN5
# Artist not in Artist Table: spotify:artist:1ZIJrAEazdX9JBXagxN6rd
# Loading missing artist: spotify:artist:1ZIJrAEazdX9JBXagxN6rd
# Artist not in Artist Table: spotify:artist:37DzvaWn66ZSdMlMjoWu36
# Loading missing artist: spotify:artist:37DzvaWn66ZSdMlMjoWu36
# Artist not in Artist Table: spotify:artist:6Z5fEH9dXRIm0TYJFO4kbj
# Loading missing artist: spotify:artist:6Z5fEH9dXRIm0TYJFO4kbj
# Artist not in Artist Table: spotify:artist:5jh9oCiZx3tfTNdAGEcLji
# Loading missing artist: spotify:artist:5jh9oCiZx3tfTNdAGEcLji
# Artist not in Artist Table: spotify:artist:1TU27RrnJnTgKae9vXCKCg
# Loading missing artist: spotify:artist:1TU27RrnJnTgKae9vXCKCg
# Artist not in Artist Table: spotify:artist:5bmHsSXdMh5W9zhFpP1EAd
# Loading missing artist: spotify:artist:5bmHsSXdMh5W9zhFpP1EAd
# Artist not in Artist Table: spotify:artist:0o39cZiBPYrandTvGWORgR
# Loading missing artist: spotify:artist:0o39cZiBPYrandTvGWORgR
# Spotify returned None for track uri: spotify:track:05iPvBxNaTbMi1twl3rnTJ
# Artist not in Artist Table: spotify:artist:1ehT67ClfcTYyQUGPSuzDQ
# Loading missing artist: spotify:artist:1ehT67ClfcTYyQUGPSuzDQ
# Artist not in Artist Table: spotify:artist:0FaUMI5rw8I5C7T77ZCNvm
# Loading missing artist: spotify:artist:0FaUMI5rw8I5C7T77ZCNvm
# Artist not in Artist Table: spotify:artist:6UyFd6ThVrTQNLv2Mqre1t
# Loading missing artist: spotify:artist:6UyFd6ThVrTQNLv2Mqre1t
# Artist not in Artist Table: spotify:artist:7wrioP33FefX2Tko7OawrV
# Loading missing artist: spotify:artist:7wrioP33FefX2Tko7OawrV
# Artist not in Artist Table: spotify:artist:4V7u4IJKCJBMjvzzVb7lQ8
# Loading missing artist: spotify:artist:4V7u4IJKCJBMjvzzVb7lQ8
# Artist not in Artist Table: spotify:artist:16jbmgn4WX3gIdwHMrWWfe
# Loading missing artist: spotify:artist:16jbmgn4WX3gIdwHMrWWfe
# Artist not in Artist Table: spotify:artist:4ClEUQ8NxfO6jVClYXE2Zh
# Loading missing artist: spotify:artist:4ClEUQ8NxfO6jVClYXE2Zh
# Artist not in Artist Table: spotify:artist:3ilCotvfDdmNlFswgfamMq
# Loading missing artist: spotify:artist:3ilCotvfDdmNlFswgfamMq
# Artist not in Artist Table: spotify:artist:7EpuKoVVOuUWj94TNCO7AR
# Loading missing artist: spotify:artist:7EpuKoVVOuUWj94TNCO7AR
# Artist not in Artist Table: spotify:artist:2vXVp4yfl4bYVu9yUlInAw
# Artist not in Artist Table: spotify:artist:3HAUdZWiqj927OSHmNKdWz
# Loading missing artist: spotify:artist:3HAUdZWiqj927OSHmNKdWz
# Artist not in Artist Table: spotify:artist:7jsU4tO9dcqdJrlX1FVNlU
# Loading missing artist: spotify:artist:7jsU4tO9dcqdJrlX1FVNlU
# Artist not in Artist Table: spotify:artist:19Wu8WhKxNX0eNXkdEzPwR
# Loading missing artist: spotify:artist:19Wu8WhKxNX0eNXkdEzPwR
# Artist not in Artist Table: spotify:artist:1BjIrnyIsQp1tImVAZfK7q
# Loading missing artist: spotify:artist:1BjIrnyIsQp1tImVAZfK7q
# Artist not in Artist Table: spotify:artist:04R1xWRUHaMdY8S9Req4iq
# Loading missing artist: spotify:artist:04R1xWRUHaMdY8S9Req4iq
# Spotify returned None for track uri: spotify:track:2nOyWmvoS9AffQFUc9I7v0
# Artist not in Artist Table: spotify:artist:4V7u4IJKCJBMjvzzVb7lQ8
# Artist not in Artist Table: spotify:artist:5TTV6plK4r2BDMUyyl7cC9
# Loading missing artist: spotify:artist:5TTV6plK4r2BDMUyyl7cC9
# Artist not in Artist Table: spotify:artist:2xHIIBOJ9pPgJ3RL374qAd
# Loading missing artist: spotify:artist:2xHIIBOJ9pPgJ3RL374qAd
# Artist not in Artist Table: spotify:artist:04QgfIIHBRS0b6XiY3kYYy
# Loading missing artist: spotify:artist:04QgfIIHBRS0b6XiY3kYYy
# Artist not in Artist Table: spotify:artist:3T6MQugN3SnovyHgr7PLUa
# Loading missing artist: spotify:artist:3T6MQugN3SnovyHgr7PLUa
# Artist not in Artist Table: spotify:artist:0LAVVn8b5gNlWQsWEm3Wf5
# Loading missing artist: spotify:artist:0LAVVn8b5gNlWQsWEm3Wf5
# Artist not in Artist Table: spotify:artist:5FhfjuIHz6wtcKdhYMfpfj
# Loading missing artist: spotify:artist:5FhfjuIHz6wtcKdhYMfpfj
# Artist not in Artist Table: spotify:artist:1oLAeeWskjYaYGrZ9Er4WX
# Loading missing artist: spotify:artist:1oLAeeWskjYaYGrZ9Er4WX
# Artist not in Artist Table: spotify:artist:24bj1SYQBPsMZMWeC5u5C7
# Loading missing artist: spotify:artist:24bj1SYQBPsMZMWeC5u5C7
# Artist not in Artist Table: spotify:artist:4q79FLWDJ5XVkL5V5kLKgo
# Loading missing artist: spotify:artist:4q79FLWDJ5XVkL5V5kLKgo
# Artist not in Artist Table: spotify:artist:5qeJAhXtdIAq1Nlg3TlQgC
# Loading missing artist: spotify:artist:5qeJAhXtdIAq1Nlg3TlQgC
# Artist not in Artist Table: spotify:artist:3zUyLsq8kGsCm9st4JMSLp
# Loading missing artist: spotify:artist:3zUyLsq8kGsCm9st4JMSLp
# Artist not in Artist Table: spotify:artist:4pvh64FRtkZqYHcHEIPlmT
# Loading missing artist: spotify:artist:4pvh64FRtkZqYHcHEIPlmT
# Artist not in Artist Table: spotify:artist:6GgOS43O6PusPfYC7mJo6k
# Loading missing artist: spotify:artist:6GgOS43O6PusPfYC7mJo6k
# Spotify returned None for track uri: spotify:track:11NIehXWtiykABhxSCRwFI
# Artist not in Artist Table: spotify:artist:025tiNv2qQdqv5kL48qZyL
# Loading missing artist: spotify:artist:025tiNv2qQdqv5kL48qZyL
# Artist not in Artist Table: spotify:artist:0OuMU8VxIABYMXNx6TLcUJ
# Loading missing artist: spotify:artist:0OuMU8VxIABYMXNx6TLcUJ
# Artist not in Artist Table: spotify:artist:0t56RUSHnfaDN3Fix1YeKJ
# Loading missing artist: spotify:artist:0t56RUSHnfaDN3Fix1YeKJ
# Artist not in Artist Table: spotify:artist:6iotJgtVvx4lwOGbauUTtJ
# Loading missing artist: spotify:artist:6iotJgtVvx4lwOGbauUTtJ
# Artist not in Artist Table: spotify:artist:2XEBwT1shtnTsG0hhuiK2D
# Loading missing artist: spotify:artist:2XEBwT1shtnTsG0hhuiK2D
# Artist not in Artist Table: spotify:artist:6p8HxXTeHr4099KlceJfX8
# Artist not in Artist Table: spotify:artist:26PcXOHyan1dzmHBBRK98G
# Loading missing artist: spotify:artist:26PcXOHyan1dzmHBBRK98G
# Artist not in Artist Table: spotify:artist:26UV9EKIInWeV0jJysGZum
# Loading missing artist: spotify:artist:26UV9EKIInWeV0jJysGZum
# Artist not in Artist Table: spotify:artist:5EZulpmAqj9YFw0doTZ1vX
# Loading missing artist: spotify:artist:5EZulpmAqj9YFw0doTZ1vX
# Artist not in Artist Table: spotify:artist:1PLakF1tFiv9zn73N2UjaN
# Loading missing artist: spotify:artist:1PLakF1tFiv9zn73N2UjaN
# Spotify returned None for track uri: spotify:track:7sRmheYLtEzJtc2MeVbT6F
# Artist not in Artist Table: spotify:artist:6UInoy9MVJElSmc5ET9G3d
# Loading missing artist: spotify:artist:6UInoy9MVJElSmc5ET9G3d
# Artist not in Artist Table: spotify:artist:5xEZOPmVLrS8645qVhPkrv
# Loading missing artist: spotify:artist:5xEZOPmVLrS8645qVhPkrv
# Artist not in Artist Table: spotify:artist:6KUGSbxgaKJR2Abxh85Ilv
# Loading missing artist: spotify:artist:6KUGSbxgaKJR2Abxh85Ilv
# Artist not in Artist Table: spotify:artist:6mPkuEEjtiuHCS86V5yw4N
# Loading missing artist: spotify:artist:6mPkuEEjtiuHCS86V5yw4N
# token():INFO:   Token refreshed
# Artist not in Artist Table: spotify:artist:6Z6goPsBmDZCBKNc2BN5Si
# Loading missing artist: spotify:artist:6Z6goPsBmDZCBKNc2BN5Si
# Artist not in Artist Table: spotify:artist:3dmxHwInu0HNxmU1F5UhJB
# Loading missing artist: spotify:artist:3dmxHwInu0HNxmU1F5UhJB
# Artist not in Artist Table: spotify:artist:6oGDuzaxim1teeU1yjhokP
# Loading missing artist: spotify:artist:6oGDuzaxim1teeU1yjhokP
# Artist not in Artist Table: spotify:artist:2duXikOTj35rOJiiU4dE8q
# Loading missing artist: spotify:artist:2duXikOTj35rOJiiU4dE8q
# Artist not in Artist Table: spotify:artist:2T2YH9fLK1CEIudHn6ui0E
# Loading missing artist: spotify:artist:2T2YH9fLK1CEIudHn6ui0E
# Artist not in Artist Table: spotify:artist:1m1JIz6iuL9B2K54LZbJbM
# Loading missing artist: spotify:artist:1m1JIz6iuL9B2K54LZbJbM
# Spotify returned None for track uri: spotify:track:4WHjf37BBXUo3WYBmJPdoU
# Artist not in Artist Table: spotify:artist:0f4Clt4QxRbyeHaToDKYPf
# Loading missing artist: spotify:artist:0f4Clt4QxRbyeHaToDKYPf
# Artist not in Artist Table: spotify:artist:1IefpZVHvnvtIbXb6iezio
# Loading missing artist: spotify:artist:1IefpZVHvnvtIbXb6iezio
# Artist not in Artist Table: spotify:artist:1Ddb7wNJHy83BpBNT2w6Xi
# Loading missing artist: spotify:artist:1Ddb7wNJHy83BpBNT2w6Xi
# Artist not in Artist Table: spotify:artist:4V2AtGnQFBjLBiQRDcAugE
# Loading missing artist: spotify:artist:4V2AtGnQFBjLBiQRDcAugE
# Artist not in Artist Table: spotify:artist:4ouh12yRoHX0VRqTi3tzSY
# Loading missing artist: spotify:artist:4ouh12yRoHX0VRqTi3tzSY
# Artist not in Artist Table: spotify:artist:0juCtHtS32tjBoYZ21mHYQ
# Loading missing artist: spotify:artist:0juCtHtS32tjBoYZ21mHYQ
# Artist not in Artist Table: spotify:artist:1tT4JJBUHbXz4gEK2ti7AW
# Loading missing artist: spotify:artist:1tT4JJBUHbXz4gEK2ti7AW
# Artist not in Artist Table: spotify:artist:5NscMoECHQfKf9VeA0l3di
# Loading missing artist: spotify:artist:5NscMoECHQfKf9VeA0l3di
# Artist not in Artist Table: spotify:artist:21yWa3M3xJJgDKumeVbtXM
# Loading missing artist: spotify:artist:21yWa3M3xJJgDKumeVbtXM
# Artist not in Artist Table: spotify:artist:4zRubvFeEcMMlgXomx1qdU
# Loading missing artist: spotify:artist:4zRubvFeEcMMlgXomx1qdU
# Artist not in Artist Table: spotify:artist:5LtL2B9LC31DesMx7ihMFc
# Loading missing artist: spotify:artist:5LtL2B9LC31DesMx7ihMFc
# Artist not in Artist Table: spotify:artist:6zJA80S2jrsIqiqukh36WP
# Loading missing artist: spotify:artist:6zJA80S2jrsIqiqukh36WP
# Artist not in Artist Table: spotify:artist:1hzoLczoLfcLOAxncTyF6d
# Loading missing artist: spotify:artist:1hzoLczoLfcLOAxncTyF6d
# Artist not in Artist Table: spotify:artist:4SOqz3TBFSmOVN4YmH4yAE
# Loading missing artist: spotify:artist:4SOqz3TBFSmOVN4YmH4yAE
# Spotify returned None for track uri: spotify:track:0KiU8DYL1oUZP0MrEHC5CS
# Artist not in Artist Table: spotify:artist:7In8nsuFDmxdbrYJybNn8h
# Loading missing artist: spotify:artist:7In8nsuFDmxdbrYJybNn8h
# Artist not in Artist Table: spotify:artist:0AZlPNSBzMbORfD8XN2wOY
# Loading missing artist: spotify:artist:0AZlPNSBzMbORfD8XN2wOY
# Artist not in Artist Table: spotify:artist:4PdU0tiKNhIsbghqOY50nn
# Loading missing artist: spotify:artist:4PdU0tiKNhIsbghqOY50nn
# Artist not in Artist Table: spotify:artist:7F2B7VhQySTBRaqJqv4NDR
# Loading missing artist: spotify:artist:7F2B7VhQySTBRaqJqv4NDR
# Artist not in Artist Table: spotify:artist:5gZhFEop4taq5UHOG8wxaX
# Loading missing artist: spotify:artist:5gZhFEop4taq5UHOG8wxaX
# Spotify returned None for track uri: spotify:track:0jcNaEKRJSwdW1Oz7LvuG7
# Artist not in Artist Table: spotify:artist:30luqBiMCfegvBWnLMRd0p
# Loading missing artist: spotify:artist:30luqBiMCfegvBWnLMRd0p
# Artist not in Artist Table: spotify:artist:6Pw1mJsIiV0DMrdpnmhUyb
# Loading missing artist: spotify:artist:6Pw1mJsIiV0DMrdpnmhUyb
# Artist not in Artist Table: spotify:artist:4NlgUPw0xKGTawMNUAsKyq
# Loading missing artist: spotify:artist:4NlgUPw0xKGTawMNUAsKyq
# Artist not in Artist Table: spotify:artist:6YZ60XhVeIKDCs0nP2yLpK
# Loading missing artist: spotify:artist:6YZ60XhVeIKDCs0nP2yLpK
# Artist not in Artist Table: spotify:artist:10YC7gfEVGGez94KMAJoLx
# Loading missing artist: spotify:artist:10YC7gfEVGGez94KMAJoLx
# Artist not in Artist Table: spotify:artist:3bMkH0P7oQbCAQX4TFx49W
# Loading missing artist: spotify:artist:3bMkH0P7oQbCAQX4TFx49W
# Artist not in Artist Table: spotify:artist:4Pxq3b6NfBYDnsbjVl8ntj
# Loading missing artist: spotify:artist:4Pxq3b6NfBYDnsbjVl8ntj
# Artist not in Artist Table: spotify:artist:7l9en45TrmOHnZHogfBcWk
# Loading missing artist: spotify:artist:7l9en45TrmOHnZHogfBcWk
# Artist not in Artist Table: spotify:artist:0CiFLuCmIQCkGw5KkopzKF
# Loading missing artist: spotify:artist:0CiFLuCmIQCkGw5KkopzKF
# Artist not in Artist Table: spotify:artist:2sVthFU8L5tg2wBK7y2u9l
# Artist not in Artist Table: spotify:artist:5lfKSWvnayeG2Q16tPM9Rh
# Loading missing artist: spotify:artist:5lfKSWvnayeG2Q16tPM9Rh
# Artist not in Artist Table: spotify:artist:7Bd76GC9TGpRm9Oh7LH7Kx
# Artist not in Artist Table: spotify:artist:1oO7WzGymvi2TV8QDbna39
# Loading missing artist: spotify:artist:1oO7WzGymvi2TV8QDbna39
# Artist not in Artist Table: spotify:artist:0F6XbRSKV9dbY94XFhaAqD
# Loading missing artist: spotify:artist:0F6XbRSKV9dbY94XFhaAqD
# Artist not in Artist Table: spotify:artist:6Eu7FPhXJeKDPxeSdWFdaB
# Loading missing artist: spotify:artist:6Eu7FPhXJeKDPxeSdWFdaB
# Artist not in Artist Table: spotify:artist:7fq6gjo2tpTW0c0kXL5oO3
# Loading missing artist: spotify:artist:7fq6gjo2tpTW0c0kXL5oO3
# Artist not in Artist Table: spotify:artist:2H2heQgOlpVh3pfnZdTDSy
# Loading missing artist: spotify:artist:2H2heQgOlpVh3pfnZdTDSy
# Artist not in Artist Table: spotify:artist:6emaUmDQOvI2ovkJdH7qBP
# Loading missing artist: spotify:artist:6emaUmDQOvI2ovkJdH7qBP
# Artist not in Artist Table: spotify:artist:3RXAq9DLWavuq6zqTiPHAt
# Loading missing artist: spotify:artist:3RXAq9DLWavuq6zqTiPHAt
# Artist not in Artist Table: spotify:artist:7vgJnbva49FV9p5EkNlKq7
# Artist not in Artist Table: spotify:artist:70IRyiXZdU8eIY56M0sBta
# Loading missing artist: spotify:artist:70IRyiXZdU8eIY56M0sBta
# Artist not in Artist Table: spotify:artist:6mQ6biniRsyq5Ky3wKmAap
# Loading missing artist: spotify:artist:6mQ6biniRsyq5Ky3wKmAap
# Artist not in Artist Table: spotify:artist:6yaMfzgtXRzZMzaHfUtGX5
# Loading missing artist: spotify:artist:6yaMfzgtXRzZMzaHfUtGX5
# Artist not in Artist Table: spotify:artist:6yrovMYhgftVImYWt9uj06
# Artist not in Artist Table: spotify:artist:5IwXv3HzxefA6Ujk6p2bxI
# Loading missing artist: spotify:artist:5IwXv3HzxefA6Ujk6p2bxI
# Spotify returned None for track uri: spotify:track:5nxkWaHFSqk1ep5wS3WelK
# Artist not in Artist Table: spotify:artist:29wSS5bDd3Ys4VMaXAvN7F
# Loading missing artist: spotify:artist:29wSS5bDd3Ys4VMaXAvN7F
# Artist not in Artist Table: spotify:artist:3B9OdGoXe2DUwoNJq3N9qY
# Artist not in Artist Table: spotify:artist:6H1yWff1QBh4tW26LFdBKP
# Loading missing artist: spotify:artist:6H1yWff1QBh4tW26LFdBKP
# Artist not in Artist Table: spotify:artist:0YHkLrAH0UrZ3H7WMFdDgh
# Loading missing artist: spotify:artist:0YHkLrAH0UrZ3H7WMFdDgh
# Spotify returned None for track uri: spotify:track:2rGNgMHMn9NvjeoUCX2wc4
# Artist not in Artist Table: spotify:artist:1CwsR8KU9boxNjuGitC3Om
# Loading missing artist: spotify:artist:1CwsR8KU9boxNjuGitC3Om
# Artist not in Artist Table: spotify:artist:3IHk5yXgKkIfnjDawpk2td
# Loading missing artist: spotify:artist:3IHk5yXgKkIfnjDawpk2td
# Artist not in Artist Table: spotify:artist:03f10q5VpYeWGfSNzzbnyr
# Loading missing artist: spotify:artist:03f10q5VpYeWGfSNzzbnyr
# Artist not in Artist Table: spotify:artist:0u4QnkIILo6KrTGES1Wcvp
# Loading missing artist: spotify:artist:0u4QnkIILo6KrTGES1Wcvp
# Artist not in Artist Table: spotify:artist:3ZdkA4UNBv6Hbj4TC2sxkq
# Loading missing artist: spotify:artist:3ZdkA4UNBv6Hbj4TC2sxkq
# Artist not in Artist Table: spotify:artist:75FDYkuEWuVAYlrghPNi4z
# Loading missing artist: spotify:artist:75FDYkuEWuVAYlrghPNi4z
# Artist not in Artist Table: spotify:artist:0PvK4Lc5Emsglbr02CQDlY
# Loading missing artist: spotify:artist:0PvK4Lc5Emsglbr02CQDlY
# Artist not in Artist Table: spotify:artist:3ltWFaAnhRF3SWe2DO3BIt
# Loading missing artist: spotify:artist:3ltWFaAnhRF3SWe2DO3BIt
# Artist not in Artist Table: spotify:artist:5G0g2q3vAaYIo4UfKMs3xB
# Artist not in Artist Table: spotify:artist:2qtN1eukzS4HalVM3Q2vXT
# Loading missing artist: spotify:artist:2qtN1eukzS4HalVM3Q2vXT
# Artist not in Artist Table: spotify:artist:5FMuT3arD0Dy4ypsZNqGdb
# Loading missing artist: spotify:artist:5FMuT3arD0Dy4ypsZNqGdb
# Artist not in Artist Table: spotify:artist:3i2IuVeuz1V5Hct3ZPWe2s
# Loading missing artist: spotify:artist:3i2IuVeuz1V5Hct3ZPWe2s
# Artist not in Artist Table: spotify:artist:7lfOqJziXX5caEiAh86k1A
# Loading missing artist: spotify:artist:7lfOqJziXX5caEiAh86k1A
# Artist not in Artist Table: spotify:artist:5xVULiv3wBC0T0lMG20mEC
# Loading missing artist: spotify:artist:5xVULiv3wBC0T0lMG20mEC
# Artist not in Artist Table: spotify:artist:7AOaJM06LzJhWJEBFHRNPr
# Loading missing artist: spotify:artist:7AOaJM06LzJhWJEBFHRNPr
# Artist not in Artist Table: spotify:artist:0b3YFggScqO5W3SbBoZPiS
# Loading missing artist: spotify:artist:0b3YFggScqO5W3SbBoZPiS
# Artist not in Artist Table: spotify:artist:4JhrkFnOh87lRmSOyyBdxH
# Loading missing artist: spotify:artist:4JhrkFnOh87lRmSOyyBdxH
# Artist not in Artist Table: spotify:artist:6IizSNkKl6dA6Od2oFzuGl
# Loading missing artist: spotify:artist:6IizSNkKl6dA6Od2oFzuGl
# Artist not in Artist Table: spotify:artist:3sYwcEFJzSpPVdJX1NLCTC
# Loading missing artist: spotify:artist:3sYwcEFJzSpPVdJX1NLCTC
# Spotify returned None for track uri: spotify:track:0crHjy8Lrvkz7oPPRq1L6E
# Artist not in Artist Table: spotify:artist:3f8QxzafNLuharjvqHmS7c
# Loading missing artist: spotify:artist:3f8QxzafNLuharjvqHmS7c
# Artist not in Artist Table: spotify:artist:7pn6a27dluoURxDkdvxqqJ
# Loading missing artist: spotify:artist:7pn6a27dluoURxDkdvxqqJ
# Artist not in Artist Table: spotify:artist:2ObH0XSPq81UuZizP2a0UQ
# Loading missing artist: spotify:artist:2ObH0XSPq81UuZizP2a0UQ
# Artist not in Artist Table: spotify:artist:27KQgRrfKASKWuRyyKml1k
# Loading missing artist: spotify:artist:27KQgRrfKASKWuRyyKml1k
# Artist not in Artist Table: spotify:artist:6rms5VWEZLBwP3kRyERa7u
# Loading missing artist: spotify:artist:6rms5VWEZLBwP3kRyERa7u
# Artist not in Artist Table: spotify:artist:6Fxl4XjkftdMEgPNkJkqqX
# Loading missing artist: spotify:artist:6Fxl4XjkftdMEgPNkJkqqX
# Artist not in Artist Table: spotify:artist:3cjV65izDdMmWE2LVwv2rb
# Loading missing artist: spotify:artist:3cjV65izDdMmWE2LVwv2rb
# Artist not in Artist Table: spotify:artist:3O3NNHrxlHo4YzpxeQplas
# Loading missing artist: spotify:artist:3O3NNHrxlHo4YzpxeQplas
# Artist not in Artist Table: spotify:artist:3uSFIs8rPUcRzKliQ6Tel9
# Loading missing artist: spotify:artist:3uSFIs8rPUcRzKliQ6Tel9
# Artist not in Artist Table: spotify:artist:51luXW6NuiCxsqVGWCoyUm
# Loading missing artist: spotify:artist:51luXW6NuiCxsqVGWCoyUm
# Artist not in Artist Table: spotify:artist:7rW4MfT0dpBB5Kr8R2OZmS
# Loading missing artist: spotify:artist:7rW4MfT0dpBB5Kr8R2OZmS
# Spotify returned None for track uri: spotify:track:5wWSOTMSqYUGFJ5Fl599LI
# Artist not in Artist Table: spotify:artist:7agqUGeCr04Op1266Xa9Ug
# Loading missing artist: spotify:artist:7agqUGeCr04Op1266Xa9Ug
# Artist not in Artist Table: spotify:artist:2gi4LZ0rJEOi15jGpQtbyb
# Loading missing artist: spotify:artist:2gi4LZ0rJEOi15jGpQtbyb
# Artist not in Artist Table: spotify:artist:2Wwy1pl5Lm8LcaXnBdlCtt
# Loading missing artist: spotify:artist:2Wwy1pl5Lm8LcaXnBdlCtt
# Artist not in Artist Table: spotify:artist:1UYLvmudFl1ERXDnAPj5WS
# Loading missing artist: spotify:artist:1UYLvmudFl1ERXDnAPj5WS
# Artist not in Artist Table: spotify:artist:7ogIRIr5ikNFXjf3nj4GeL
# Loading missing artist: spotify:artist:7ogIRIr5ikNFXjf3nj4GeL
# Artist not in Artist Table: spotify:artist:3eFwYVBFUKjDkNSdc5lj0b
# Loading missing artist: spotify:artist:3eFwYVBFUKjDkNSdc5lj0b
# Artist not in Artist Table: spotify:artist:0p6iNlkB41r1JtxZ3F6JMJ
# Loading missing artist: spotify:artist:0p6iNlkB41r1JtxZ3F6JMJ
# Artist not in Artist Table: spotify:artist:1p6sivjtLEhWIiZfL61Anu
# Loading missing artist: spotify:artist:1p6sivjtLEhWIiZfL61Anu
# Artist not in Artist Table: spotify:artist:0CiFLuCmIQCkGw5KkopzKF
# Artist not in Artist Table: spotify:artist:4gSrksboUZ0u6MSIgRJyBg
# Artist not in Artist Table: spotify:artist:1FjeDelzvqDfBffoHwsQkE
# Loading missing artist: spotify:artist:1FjeDelzvqDfBffoHwsQkE
# Artist not in Artist Table: spotify:artist:08YrMlQ0BwO0feXJhZRwGw
# Loading missing artist: spotify:artist:08YrMlQ0BwO0feXJhZRwGw
# Artist not in Artist Table: spotify:artist:6yrovMYhgftVImYWt9uj06
# Artist not in Artist Table: spotify:artist:4Tq5WcGnPrbW1naEPVv1Ya
# Loading missing artist: spotify:artist:4Tq5WcGnPrbW1naEPVv1Ya
# Artist not in Artist Table: spotify:artist:5D5ipJARXGLdDIo7fje2GX
# Loading missing artist: spotify:artist:5D5ipJARXGLdDIo7fje2GX
# Artist not in Artist Table: spotify:artist:3H6CaRooDAoCeRCpYwOXj2
# Loading missing artist: spotify:artist:3H6CaRooDAoCeRCpYwOXj2
# Artist not in Artist Table: spotify:artist:42VMawkZqUxfqGQxmlvIr8
# Loading missing artist: spotify:artist:42VMawkZqUxfqGQxmlvIr8
# Artist not in Artist Table: spotify:artist:22YaTeakBauJ5h9iMDVrAR
# Loading missing artist: spotify:artist:22YaTeakBauJ5h9iMDVrAR
# Artist not in Artist Table: spotify:artist:0UN0K60uEgTjkuyR390qOp
# Loading missing artist: spotify:artist:0UN0K60uEgTjkuyR390qOp
# Artist not in Artist Table: spotify:artist:0U8abHcCZBdVMcKq40Ma6I
# Loading missing artist: spotify:artist:0U8abHcCZBdVMcKq40Ma6I
# Artist not in Artist Table: spotify:artist:2A24QkmtTRugMSJOb0K9Ae
# Loading missing artist: spotify:artist:2A24QkmtTRugMSJOb0K9Ae
# Artist not in Artist Table: spotify:artist:1ehT67ClfcTYyQUGPSuzDQ
# Artist not in Artist Table: spotify:artist:65mbmhe15TRvNaTwSt5Doc
# Loading missing artist: spotify:artist:65mbmhe15TRvNaTwSt5Doc
# Artist not in Artist Table: spotify:artist:3T6MQugN3SnovyHgr7PLUa
# Artist not in Artist Table: spotify:artist:6yaMfzgtXRzZMzaHfUtGX5
# Artist not in Artist Table: spotify:artist:4I7YlJwAY1br8tiOtdKjw6
# Loading missing artist: spotify:artist:4I7YlJwAY1br8tiOtdKjw6
# Artist not in Artist Table: spotify:artist:42q0AVjrklQkkvRppLFr03
# Loading missing artist: spotify:artist:42q0AVjrklQkkvRppLFr03
# Artist not in Artist Table: spotify:artist:3wCyJ7W81Z1QHpa49mvgPW
# Loading missing artist: spotify:artist:3wCyJ7W81Z1QHpa49mvgPW
# Spotify returned None for track uri: spotify:track:1SuyTHBUdlsDJeZ77viTVY
# Artist not in Artist Table: spotify:artist:01U1kYJ2rwM8OoSd8pAowT
# Loading missing artist: spotify:artist:01U1kYJ2rwM8OoSd8pAowT
# Artist not in Artist Table: spotify:artist:5dZKbhRYNNGR1ntBJiFRxz
# Loading missing artist: spotify:artist:5dZKbhRYNNGR1ntBJiFRxz
# Artist not in Artist Table: spotify:artist:4XzsOuqFltgBcdHF3RZQbh
# Loading missing artist: spotify:artist:4XzsOuqFltgBcdHF3RZQbh
# Artist not in Artist Table: spotify:artist:6tVsUWjip0Tnp1EyCRX5XH
# Loading missing artist: spotify:artist:6tVsUWjip0Tnp1EyCRX5XH
# Artist not in Artist Table: spotify:artist:1ehT67ClfcTYyQUGPSuzDQ
# Artist not in Artist Table: spotify:artist:2mVUdPq7evlUNzq2rYys8S
# Loading missing artist: spotify:artist:2mVUdPq7evlUNzq2rYys8S
# Artist not in Artist Table: spotify:artist:1dtCZzVp9Y8HLuMngXTxZV
# Loading missing artist: spotify:artist:1dtCZzVp9Y8HLuMngXTxZV
# Artist not in Artist Table: spotify:artist:3buZl5JKgOpBl8Mrpfve6m
# Loading missing artist: spotify:artist:3buZl5JKgOpBl8Mrpfve6m
# Artist not in Artist Table: spotify:artist:1ZfhyWZ9byvjFKEzBSa81I
# Loading missing artist: spotify:artist:1ZfhyWZ9byvjFKEzBSa81I
# Artist not in Artist Table: spotify:artist:0TfShYbxL73wcYNef1F5KT
# Loading missing artist: spotify:artist:0TfShYbxL73wcYNef1F5KT
# Artist not in Artist Table: spotify:artist:1zmx3NwOp6vR4qEjmhSiLL
# Loading missing artist: spotify:artist:1zmx3NwOp6vR4qEjmhSiLL
# token():INFO:   Token refreshed
# Artist not in Artist Table: spotify:artist:3ccpTBrgQOIdOMphrKMVHC
# Loading missing artist: spotify:artist:3ccpTBrgQOIdOMphrKMVHC
# Artist not in Artist Table: spotify:artist:3ilCotvfDdmNlFswgfamMq
# Artist not in Artist Table: spotify:artist:27fuPMau4U3O3Fq1alFXCM
# Loading missing artist: spotify:artist:27fuPMau4U3O3Fq1alFXCM
# Artist not in Artist Table: spotify:artist:3as2cN9jzn4TUHPpXFf2qU
# Loading missing artist: spotify:artist:3as2cN9jzn4TUHPpXFf2qU
# Artist not in Artist Table: spotify:artist:2G5f9RHEFhe7uiUwDyFnGD
# Loading missing artist: spotify:artist:2G5f9RHEFhe7uiUwDyFnGD
# Artist not in Artist Table: spotify:artist:4Mp4FOTjHHQlFJki4p1lpZ
# Loading missing artist: spotify:artist:4Mp4FOTjHHQlFJki4p1lpZ
# Artist not in Artist Table: spotify:artist:5FrBHKW9H3GjG5DayI84Ad
# Loading missing artist: spotify:artist:5FrBHKW9H3GjG5DayI84Ad
# Artist not in Artist Table: spotify:artist:5fNZ3wa4cWyYpwQyJyvdis
# Loading missing artist: spotify:artist:5fNZ3wa4cWyYpwQyJyvdis
# Artist not in Artist Table: spotify:artist:4vYBWLnOmkOg5lLH0KB5PH
# Loading missing artist: spotify:artist:4vYBWLnOmkOg5lLH0KB5PH
# Artist not in Artist Table: spotify:artist:1WlI44ldPQ6vR0JMQfdoJO
# Loading missing artist: spotify:artist:1WlI44ldPQ6vR0JMQfdoJO
# Artist not in Artist Table: spotify:artist:1u9XTBITnSgp4G2oFOEU3A
# Loading missing artist: spotify:artist:1u9XTBITnSgp4G2oFOEU3A
# Artist not in Artist Table: spotify:artist:67z6XWU5ig0dx46fl1GDTd
# Loading missing artist: spotify:artist:67z6XWU5ig0dx46fl1GDTd
# Artist not in Artist Table: spotify:artist:5pq14S4AFVXGSyYbIGJC6Q
# Loading missing artist: spotify:artist:5pq14S4AFVXGSyYbIGJC6Q
# Spotify returned None for track uri: spotify:track:18JnPuzORjaFXgdcVJWjjI
# Artist not in Artist Table: spotify:artist:6GXpEIouURly5PQjtAoTKr
# Loading missing artist: spotify:artist:6GXpEIouURly5PQjtAoTKr
# Artist not in Artist Table: spotify:artist:3eRX5vJLVMuteL36PaWL7g
# Loading missing artist: spotify:artist:3eRX5vJLVMuteL36PaWL7g
# Artist not in Artist Table: spotify:artist:5YHemeVaZnBOVAHFMSzMcV
# Loading missing artist: spotify:artist:5YHemeVaZnBOVAHFMSzMcV
# Artist not in Artist Table: spotify:artist:0dch9LscX1EjWQLgCJa1NI
# Loading missing artist: spotify:artist:0dch9LscX1EjWQLgCJa1NI
# Artist not in Artist Table: spotify:artist:06zS0fTnfMX9Bg3UTfKbD9
# Artist not in Artist Table: spotify:artist:0bDdOBGVCFVt0f8N9ldW1k
# Loading missing artist: spotify:artist:0bDdOBGVCFVt0f8N9ldW1k
# Artist not in Artist Table: spotify:artist:1kydV1RJaCH3wePowuxDhB
# Artist not in Artist Table: spotify:artist:65mbmhe15TRvNaTwSt5Doc
# Artist not in Artist Table: spotify:artist:42dx5SO3douFDpuYFal8UZ
# Loading missing artist: spotify:artist:42dx5SO3douFDpuYFal8UZ
# Artist not in Artist Table: spotify:artist:6NammEMEFZFlr0l8STaEQs
# Loading missing artist: spotify:artist:6NammEMEFZFlr0l8STaEQs
# Artist not in Artist Table: spotify:artist:3TFGD9WNYNR4PKT1rOIOUy
# Loading missing artist: spotify:artist:3TFGD9WNYNR4PKT1rOIOUy
# Artist not in Artist Table: spotify:artist:2BlCyn1pAc9oQia2WVjUAs
# Loading missing artist: spotify:artist:2BlCyn1pAc9oQia2WVjUAs
# Artist not in Artist Table: spotify:artist:2RS1R0tueoL8EJXTSBAt2F
# Loading missing artist: spotify:artist:2RS1R0tueoL8EJXTSBAt2F
# Artist not in Artist Table: spotify:artist:2eQPDhVoSa5aeWROa5wfxZ
# Artist not in Artist Table: spotify:artist:1Nytin66IaC1zSi4wufnDD
# Loading missing artist: spotify:artist:1Nytin66IaC1zSi4wufnDD
# Artist not in Artist Table: spotify:artist:3gLqZEsslb3RIyDcCR3Faq
# Loading missing artist: spotify:artist:3gLqZEsslb3RIyDcCR3Faq
# Artist not in Artist Table: spotify:artist:4dBMl1epCOf6FAtkp9ayFu
# Loading missing artist: spotify:artist:4dBMl1epCOf6FAtkp9ayFu
# Artist not in Artist Table: spotify:artist:6ysVu0eJzUxwlvhUKxrxG9
# Loading missing artist: spotify:artist:6ysVu0eJzUxwlvhUKxrxG9
# Artist not in Artist Table: spotify:artist:2vFXOKUQ2uhI9D8vKozoK6
# Loading missing artist: spotify:artist:2vFXOKUQ2uhI9D8vKozoK6
# Artist not in Artist Table: spotify:artist:3WZhOX9lbeUUagirRi1RQW
# Artist not in Artist Table: spotify:artist:3buZl5JKgOpBl8Mrpfve6m
# Artist not in Artist Table: spotify:artist:3J44LjCSFOFm2Ft11coMId
# Artist not in Artist Table: spotify:artist:3AGZBY5z2TLXTYd3Foh718
# Loading missing artist: spotify:artist:3AGZBY5z2TLXTYd3Foh718
# Artist not in Artist Table: spotify:artist:79BdZx2uubCGfzZmVLZniA
# Loading missing artist: spotify:artist:79BdZx2uubCGfzZmVLZniA
# Artist not in Artist Table: spotify:artist:6BVjnrhoq9PZDHIkjRaV3M
# Loading missing artist: spotify:artist:6BVjnrhoq9PZDHIkjRaV3M
# Artist not in Artist Table: spotify:artist:2ttL0DCEIllR7eRMsDmkAX
# Loading missing artist: spotify:artist:2ttL0DCEIllR7eRMsDmkAX
# Artist not in Artist Table: spotify:artist:72T4k0vAzQnVbBZEipp9X8
# Loading missing artist: spotify:artist:72T4k0vAzQnVbBZEipp9X8
# Artist not in Artist Table: spotify:artist:7qKWQnE3S7v8m3rLwMVdGg
# Loading missing artist: spotify:artist:7qKWQnE3S7v8m3rLwMVdGg
# Artist not in Artist Table: spotify:artist:53ZFQuwiG5WYoG4lef7nOk
# Loading missing artist: spotify:artist:53ZFQuwiG5WYoG4lef7nOk
# Artist not in Artist Table: spotify:artist:2SlUR9DxA1FZqUSviWat1f
# Loading missing artist: spotify:artist:2SlUR9DxA1FZqUSviWat1f
# Artist not in Artist Table: spotify:artist:2vIKM7x5kKzKR9rIMBejxr
# Loading missing artist: spotify:artist:2vIKM7x5kKzKR9rIMBejxr
# Artist not in Artist Table: spotify:artist:0bDdOBGVCFVt0f8N9ldW1k
# Artist not in Artist Table: spotify:artist:6zkjA8pYm3xU4GG42fS201
# Loading missing artist: spotify:artist:6zkjA8pYm3xU4GG42fS201
# Artist not in Artist Table: spotify:artist:5NuVOK1ydODBWwM1QCFY2V
# Loading missing artist: spotify:artist:5NuVOK1ydODBWwM1QCFY2V
# Artist not in Artist Table: spotify:artist:5P0713TH0hfITBogErNmgp
# Loading missing artist: spotify:artist:5P0713TH0hfITBogErNmgp
# Spotify returned None for track uri: spotify:track:5mbnHTT20qMKEbj31NmpHF
# Artist not in Artist Table: spotify:artist:5AAAM6PWNEvRnhBnTZOFji
# Loading missing artist: spotify:artist:5AAAM6PWNEvRnhBnTZOFji
# Artist not in Artist Table: spotify:artist:2VvKZTmM6waQ64A1erQkto
# Loading missing artist: spotify:artist:2VvKZTmM6waQ64A1erQkto
# Artist not in Artist Table: spotify:artist:6IemnVfxt5UkSOa4IBArHc
# Loading missing artist: spotify:artist:6IemnVfxt5UkSOa4IBArHc
# Artist not in Artist Table: spotify:artist:1kydV1RJaCH3wePowuxDhB
# Artist not in Artist Table: spotify:artist:3TIlkDLL5iVkwYjKo5KUQZ
# Loading missing artist: spotify:artist:3TIlkDLL5iVkwYjKo5KUQZ
# Artist not in Artist Table: spotify:artist:2ZgwhAs2oGFi44aEaitmyI
# Loading missing artist: spotify:artist:2ZgwhAs2oGFi44aEaitmyI
# Artist not in Artist Table: spotify:artist:2CYCakORoguvscDruDYkkW
# Loading missing artist: spotify:artist:2CYCakORoguvscDruDYkkW
# Artist not in Artist Table: spotify:artist:597Lj3JwfCSRfhbDY7Wse2
# Loading missing artist: spotify:artist:597Lj3JwfCSRfhbDY7Wse2
# Artist not in Artist Table: spotify:artist:1rlyNVA9Obzajhz30Xuk5a
# Loading missing artist: spotify:artist:1rlyNVA9Obzajhz30Xuk5a
# Artist not in Artist Table: spotify:artist:399Bn6jx0mqMTkNf3bfqN4
# Loading missing artist: spotify:artist:399Bn6jx0mqMTkNf3bfqN4
# Artist not in Artist Table: spotify:artist:7F2B7VhQySTBRaqJqv4NDR
# Spotify returned None for track uri: spotify:track:6cePxNkX02pGoQHhiVohO1
# Artist not in Artist Table: spotify:artist:3B9OdGoXe2DUwoNJq3N9qY
# Artist not in Artist Table: spotify:artist:1MHW9UQC8LMXQoxb8mu3wq
# Loading missing artist: spotify:artist:1MHW9UQC8LMXQoxb8mu3wq
# Artist not in Artist Table: spotify:artist:4EQzLonQCkUbCCnAKkyaTX
# Loading missing artist: spotify:artist:4EQzLonQCkUbCCnAKkyaTX
# Artist not in Artist Table: spotify:artist:1Y5ctqMVNhVvPvqqYYy5hP
# Loading missing artist: spotify:artist:1Y5ctqMVNhVvPvqqYYy5hP
# Artist not in Artist Table: spotify:artist:1Zh7079rBjsV8Fuo81BpJI
# Loading missing artist: spotify:artist:1Zh7079rBjsV8Fuo81BpJI
# Artist not in Artist Table: spotify:artist:4XzVQfkhtgfdvrzOnsjDdA
# Loading missing artist: spotify:artist:4XzVQfkhtgfdvrzOnsjDdA
# Artist not in Artist Table: spotify:artist:1kydV1RJaCH3wePowuxDhB
# Artist not in Artist Table: spotify:artist:4bDYAucgAfUgpAPTvJBuGG
# Loading missing artist: spotify:artist:4bDYAucgAfUgpAPTvJBuGG
# Spotify returned None for track uri: spotify:track:5WJ2L1bDMN2mXiwyQaXUz0
# Artist not in Artist Table: spotify:artist:0p5nor5JEcvNOqOxnAeBvc
# Loading missing artist: spotify:artist:0p5nor5JEcvNOqOxnAeBvc
# Artist not in Artist Table: spotify:artist:6bY00PLfv1bngY6hDZsPFw
# Artist not in Artist Table: spotify:artist:0ScVVtSHdGjvBmJy8kOFNy
# Loading missing artist: spotify:artist:0ScVVtSHdGjvBmJy8kOFNy
# Artist not in Artist Table: spotify:artist:3ADkb0E181ysVQIRtQpXKO
# Loading missing artist: spotify:artist:3ADkb0E181ysVQIRtQpXKO
# Artist not in Artist Table: spotify:artist:08W9V4YCFoi76FNjqtjHng
# Loading missing artist: spotify:artist:08W9V4YCFoi76FNjqtjHng
# Artist not in Artist Table: spotify:artist:5T4zvVxfRyAFhjJdFXKK75
# Loading missing artist: spotify:artist:5T4zvVxfRyAFhjJdFXKK75
# Artist not in Artist Table: spotify:artist:6JQssBTNKroSLeF6Gb4R43
# Loading missing artist: spotify:artist:6JQssBTNKroSLeF6Gb4R43
# Artist not in Artist Table: spotify:artist:2FSjGnlbIq2ecreQei2nMV
# Loading missing artist: spotify:artist:2FSjGnlbIq2ecreQei2nMV
# Artist not in Artist Table: spotify:artist:75myVgZbKQkWpyHAlLUCmG
# Artist not in Artist Table: spotify:artist:3e7KVnSiZjsBkReSv0L6db
# Loading missing artist: spotify:artist:3e7KVnSiZjsBkReSv0L6db
# Spotify returned None for track uri: spotify:track:0zA7okPLt66GVf2ilDN9Eq
# Artist not in Artist Table: spotify:artist:6qodKfuDsMjBWIIg8CWQ6D
# Loading missing artist: spotify:artist:6qodKfuDsMjBWIIg8CWQ6D
# Artist not in Artist Table: spotify:artist:011End1HfeHnGrLbSkcoLG
# Loading missing artist: spotify:artist:011End1HfeHnGrLbSkcoLG
# Artist not in Artist Table: spotify:artist:4ETQVh3cFIjfiNmZmGZRKu
# Loading missing artist: spotify:artist:4ETQVh3cFIjfiNmZmGZRKu
# Artist not in Artist Table: spotify:artist:3atxQshYBzwbtD2mVw02jr
# Loading missing artist: spotify:artist:3atxQshYBzwbtD2mVw02jr
# Artist not in Artist Table: spotify:artist:3IHk5yXgKkIfnjDawpk2td
# Artist not in Artist Table: spotify:artist:4HBe2DscKcmFAjL1ml3Lx6
# Loading missing artist: spotify:artist:4HBe2DscKcmFAjL1ml3Lx6
# Artist not in Artist Table: spotify:artist:4Krht8w9QMmsvzxv1euAGh
# Loading missing artist: spotify:artist:4Krht8w9QMmsvzxv1euAGh
# Artist not in Artist Table: spotify:artist:6uZIQReLKidm8YFmxRC7Sh
# Loading missing artist: spotify:artist:6uZIQReLKidm8YFmxRC7Sh
# Artist not in Artist Table: spotify:artist:57EsOUuGJeBq8uOJLgzzEe
# Loading missing artist: spotify:artist:57EsOUuGJeBq8uOJLgzzEe
# Artist not in Artist Table: spotify:artist:08HRN7hYxMxJ4BOMP0TJK6
# Loading missing artist: spotify:artist:08HRN7hYxMxJ4BOMP0TJK6
# Artist not in Artist Table: spotify:artist:5C0VpslPBd7fgYkuRGLdKJ
# Artist not in Artist Table: spotify:artist:6mBhIlUMDE2QT3uigYxTzM
# Loading missing artist: spotify:artist:6mBhIlUMDE2QT3uigYxTzM
# Artist not in Artist Table: spotify:artist:67f1VAFWZnA8kvKT5rJDyS
# Loading missing artist: spotify:artist:67f1VAFWZnA8kvKT5rJDyS
# Artist not in Artist Table: spotify:artist:6BMQo3hxi4qwLiZpHKK5iL
# Loading missing artist: spotify:artist:6BMQo3hxi4qwLiZpHKK5iL
# Artist not in Artist Table: spotify:artist:6l7quaU13g2g9cBz8STEuq
# Artist not in Artist Table: spotify:artist:5Kr4ApPokBE2UGZladvkIf
# Loading missing artist: spotify:artist:5Kr4ApPokBE2UGZladvkIf
# Artist not in Artist Table: spotify:artist:2vXVp4yfl4bYVu9yUlInAw
# Artist not in Artist Table: spotify:artist:7dUNKhz7HdxExteqcREGLi
# Loading missing artist: spotify:artist:7dUNKhz7HdxExteqcREGLi
# Artist not in Artist Table: spotify:artist:0E35qGkeLpZKk7sx8Ctlav
# Loading missing artist: spotify:artist:0E35qGkeLpZKk7sx8Ctlav
# Artist not in Artist Table: spotify:artist:411gxyOZ3IlTwiEmtLbODl
# Loading missing artist: spotify:artist:411gxyOZ3IlTwiEmtLbODl
# Artist not in Artist Table: spotify:artist:4WBG6uQSVALWMWV6dGSO2E
# Loading missing artist: spotify:artist:4WBG6uQSVALWMWV6dGSO2E
# Artist not in Artist Table: spotify:artist:6VtrGMVv6lZZmwoZ7qu8LR
# Loading missing artist: spotify:artist:6VtrGMVv6lZZmwoZ7qu8LR
# Artist not in Artist Table: spotify:artist:22YaTeakBauJ5h9iMDVrAR
# Artist not in Artist Table: spotify:artist:6KldxzarIfA0ry71Lb6L0n
# Loading missing artist: spotify:artist:6KldxzarIfA0ry71Lb6L0n
# Artist not in Artist Table: spotify:artist:0TKIN6ssV2jhUlRm3r7U4z
# Loading missing artist: spotify:artist:0TKIN6ssV2jhUlRm3r7U4z
# Artist not in Artist Table: spotify:artist:0Y0DQdLIIlZ8kD3HvEtakI
# Loading missing artist: spotify:artist:0Y0DQdLIIlZ8kD3HvEtakI
# Artist not in Artist Table: spotify:artist:3ylwSKkgfwc3y1SFa1yVwz
# Loading missing artist: spotify:artist:3ylwSKkgfwc3y1SFa1yVwz
# Artist not in Artist Table: spotify:artist:0wEdsSeyVcXWPrsBvWVOgF
# Loading missing artist: spotify:artist:0wEdsSeyVcXWPrsBvWVOgF
# Artist not in Artist Table: spotify:artist:2J0TXJifL8vZUk11Bc7fGE
# Loading missing artist: spotify:artist:2J0TXJifL8vZUk11Bc7fGE
# Artist not in Artist Table: spotify:artist:3yVOHNWnsCHuaaOCnflSRD
# Loading missing artist: spotify:artist:3yVOHNWnsCHuaaOCnflSRD
# Spotify returned None for track uri: spotify:track:3o9RCvd6Vg8wD8b9SLBhDr
# Spotify returned None for track uri: spotify:track:35yeDq2AngBhej5A3qNnpX
# Artist not in Artist Table: spotify:artist:4t6FnfFNUfY8nXUdot2H0d
# Loading missing artist: spotify:artist:4t6FnfFNUfY8nXUdot2H0d
# Artist not in Artist Table: spotify:artist:0J3t4PcvWKdUlpiBnDtWbd
# Loading missing artist: spotify:artist:0J3t4PcvWKdUlpiBnDtWbd
# Artist not in Artist Table: spotify:artist:4vYBWLnOmkOg5lLH0KB5PH
# Artist not in Artist Table: spotify:artist:06zS0fTnfMX9Bg3UTfKbD9
# Spotify returned None for track uri: spotify:track:6UnswPYevOy5rxgZPslKGn
# Artist not in Artist Table: spotify:artist:3haPAcAMMngBtugMQSIaSg
# Loading missing artist: spotify:artist:3haPAcAMMngBtugMQSIaSg
# Artist not in Artist Table: spotify:artist:1evtVBE3Xj2MzWAjOiNDcS
# Artist not in Artist Table: spotify:artist:6JGikidxLjpod22lKlcB9G
# Loading missing artist: spotify:artist:6JGikidxLjpod22lKlcB9G
# Artist not in Artist Table: spotify:artist:107CG0UhUl9GJnPwF83N63
# Loading missing artist: spotify:artist:107CG0UhUl9GJnPwF83N63
# Artist not in Artist Table: spotify:artist:597Lj3JwfCSRfhbDY7Wse2
# Artist not in Artist Table: spotify:artist:6bY00PLfv1bngY6hDZsPFw
# Artist not in Artist Table: spotify:artist:2foAanYCza7knczRDB8DFt
# Loading missing artist: spotify:artist:2foAanYCza7knczRDB8DFt
# Artist not in Artist Table: spotify:artist:5mJ1y1AATJvQJodIOkbXeU
# Loading missing artist: spotify:artist:5mJ1y1AATJvQJodIOkbXeU
# Artist not in Artist Table: spotify:artist:4Z1o4tq9yG3WnWFHw28bYk
# Loading missing artist: spotify:artist:4Z1o4tq9yG3WnWFHw28bYk
# Artist not in Artist Table: spotify:artist:18x30Q8LrJCYOKL7dR8OXD
# Loading missing artist: spotify:artist:18x30Q8LrJCYOKL7dR8OXD
# Artist not in Artist Table: spotify:artist:5b2jT1Vc6eiEKdJgVSvtLz
# Loading missing artist: spotify:artist:5b2jT1Vc6eiEKdJgVSvtLz
# Artist not in Artist Table: spotify:artist:7sZzqjfZ0pPovEk2VeIMJp
# Loading missing artist: spotify:artist:7sZzqjfZ0pPovEk2VeIMJp
# Artist not in Artist Table: spotify:artist:4X8K9Iq3DosqestqWr3o2m
# Loading missing artist: spotify:artist:4X8K9Iq3DosqestqWr3o2m
# Artist not in Artist Table: spotify:artist:1fAotS2jUxpI8bnIxd5cIR
# Loading missing artist: spotify:artist:1fAotS2jUxpI8bnIxd5cIR
# Artist not in Artist Table: spotify:artist:792YF1QhWcZM8Uq80HkjT9
# Loading missing artist: spotify:artist:792YF1QhWcZM8Uq80HkjT9
# Artist not in Artist Table: spotify:artist:7HSEBupchImXF7e4L63tpb
# Loading missing artist: spotify:artist:7HSEBupchImXF7e4L63tpb
# ...
# Artist not in Artist Table: spotify:artist:0q8KW3cScU9CjB1cxEZwaS
# Loading missing artist: spotify:artist:0q8KW3cScU9CjB1cxEZwaS
# Artist not in Artist Table: spotify:artist:1kydV1RJaCH3wePowuxDhB
# Artist not in Artist Table: spotify:artist:4yrOIPlpAaSZ0Xb2n5Wdyu
# Artist not in Artist Table: spotify:artist:692sqZdmqkQjdCk87QECpd
# Loading missing artist: spotify:artist:692sqZdmqkQjdCk87QECpd
# Artist not in Artist Table: spotify:artist:06nPVbWMznES8cks2y4q8b
# Loading missing artist: spotify:artist:06nPVbWMznES8cks2y4q8b
# Artist not in Artist Table: spotify:artist:4qJk7v2FLcN2VasAGi9Mxy
# Loading missing artist: spotify:artist:4qJk7v2FLcN2VasAGi9Mxy
# Artist not in Artist Table: spotify:artist:7AOaJM06LzJhWJEBFHRNPr
# Artist not in Artist Table: spotify:artist:57EsOUuGJeBq8uOJLgzzEe
# Artist not in Artist Table: spotify:artist:5unpk89AASvQ63FCdF3Jxf
# Loading missing artist: spotify:artist:5unpk89AASvQ63FCdF3Jxf
# Artist not in Artist Table: spotify:artist:6l7quaU13g2g9cBz8STEuq
# Artist not in Artist Table: spotify:artist:4XUuVsuDGtBtLoJprpnmpR
# Loading missing artist: spotify:artist:4XUuVsuDGtBtLoJprpnmpR
# Artist not in Artist Table: spotify:artist:14tToftzUXlFOnrR5ojQxu
# Loading missing artist: spotify:artist:14tToftzUXlFOnrR5ojQxu
# Artist not in Artist Table: spotify:artist:23a7RRnIpe5rS97rEU0MzC
# Spotify returned None for track uri: spotify:track:4GBC5hRigIgKFpsPsF0YyH
# Artist not in Artist Table: spotify:artist:5BjywbhsH84zRy8olzFbZT
# Loading missing artist: spotify:artist:5BjywbhsH84zRy8olzFbZT
# Artist not in Artist Table: spotify:artist:3wVEJKeTS4XjYSmuHBBjwZ
# Loading missing artist: spotify:artist:3wVEJKeTS4XjYSmuHBBjwZ
# Artist not in Artist Table: spotify:artist:2eRzassxov0SS03JFEC9KR
# Loading missing artist: spotify:artist:2eRzassxov0SS03JFEC9KR
# Artist not in Artist Table: spotify:artist:5OwbuiNScVunjVVbckgYU0
# Loading missing artist: spotify:artist:5OwbuiNScVunjVVbckgYU0
# Artist not in Artist Table: spotify:artist:21po1pr0KnBvgp6tS3FCj0
# Loading missing artist: spotify:artist:21po1pr0KnBvgp6tS3FCj0
# Artist not in Artist Table: spotify:artist:5PHv8QL7H1mrd6YOzsL0bM
# Loading missing artist: spotify:artist:5PHv8QL7H1mrd6YOzsL0bM
# Spotify returned None for track uri: spotify:track:3e3RrqJidaVj2EFxCECYjD
# Artist not in Artist Table: spotify:artist:4RVCpEiZxGq53mAu1Do2KR
# Artist not in Artist Table: spotify:artist:0ISoHHwVZzHFrxgHN2HjYv
# Loading missing artist: spotify:artist:0ISoHHwVZzHFrxgHN2HjYv
# Artist not in Artist Table: spotify:artist:3SI7XYRKT9cqAgju2vhf67
# Loading missing artist: spotify:artist:3SI7XYRKT9cqAgju2vhf67
# Artist not in Artist Table: spotify:artist:4treG8mEpgxPtGOdcBAlcB
# Loading missing artist: spotify:artist:4treG8mEpgxPtGOdcBAlcB
# Artist not in Artist Table: spotify:artist:2WhRghr33DV5WbgSYHRfE2
# Loading missing artist: spotify:artist:2WhRghr33DV5WbgSYHRfE2
# Artist not in Artist Table: spotify:artist:21jIk1sXKLzlGlc0pg9UUY
# Artist not in Artist Table: spotify:artist:5Vk7hK1IiuB8j5T9lrvr95
# Loading missing artist: spotify:artist:5Vk7hK1IiuB8j5T9lrvr95
# Artist not in Artist Table: spotify:artist:4Wwlum7Ogcslp1Kk2Az0bA
# Artist not in Artist Table: spotify:artist:6YuAcsaG8YM5Rm2OKsd1Sw
# Artist not in Artist Table: spotify:artist:67JtyNdKqgARY5yYNWHnf0
# Loading missing artist: spotify:artist:67JtyNdKqgARY5yYNWHnf0
# Artist not in Artist Table: spotify:artist:4y3ixK7dGQIx172hmztdjm
# Loading missing artist: spotify:artist:4y3ixK7dGQIx172hmztdjm
# Artist not in Artist Table: spotify:artist:3BaFnuLxGRNUdqlVQE2uTd
# Loading missing artist: spotify:artist:3BaFnuLxGRNUdqlVQE2uTd
# Artist not in Artist Table: spotify:artist:3ilCotvfDdmNlFswgfamMq
# Artist not in Artist Table: spotify:artist:5jeuQkP4cxNSzpGSLr60UX
# Loading missing artist: spotify:artist:5jeuQkP4cxNSzpGSLr60UX
# Artist not in Artist Table: spotify:artist:0s13QZWOmMaND1Q6cn8SPZ
# Loading missing artist: spotify:artist:0s13QZWOmMaND1Q6cn8SPZ
# Artist not in Artist Table: spotify:artist:7Bd76GC9TGpRm9Oh7LH7Kx
# Artist not in Artist Table: spotify:artist:64bkd3Cql2VeQBIfl5tjCC
# Artist not in Artist Table: spotify:artist:0ngUeF0DGpYmPec80MqSi1
# Loading missing artist: spotify:artist:0ngUeF0DGpYmPec80MqSi1
# Artist not in Artist Table: spotify:artist:7sLgqMMl7lWfWa69ABZds1
# Artist not in Artist Table: spotify:artist:4WYUozUi0ap1WyOyIsOAJ7
# Loading missing artist: spotify:artist:4WYUozUi0ap1WyOyIsOAJ7
# Artist not in Artist Table: spotify:artist:0JeMmlHwTUxUw2pzXbrd8C
# Loading missing artist: spotify:artist:0JeMmlHwTUxUw2pzXbrd8C
# Artist not in Artist Table: spotify:artist:4nw2gtmPKruETtPKUpd1q2
# Loading missing artist: spotify:artist:4nw2gtmPKruETtPKUpd1q2
# Artist not in Artist Table: spotify:artist:4Oc6YddDw6YWdx4wYfyd3S
# Loading missing artist: spotify:artist:4Oc6YddDw6YWdx4wYfyd3S
# Artist not in Artist Table: spotify:artist:0hJFU2GoQ9eDQ0RIsr4uWW
# Loading missing artist: spotify:artist:0hJFU2GoQ9eDQ0RIsr4uWW
# Artist not in Artist Table: spotify:artist:1Z1r6yBMu0bc4JZQPUP7Ks
# Loading missing artist: spotify:artist:1Z1r6yBMu0bc4JZQPUP7Ks
# Artist not in Artist Table: spotify:artist:08HRN7hYxMxJ4BOMP0TJK6
# Artist not in Artist Table: spotify:artist:6JYedwPn7zEWlTSUda9mev
# Artist not in Artist Table: spotify:artist:4ouh12yRoHX0VRqTi3tzSY
# Artist not in Artist Table: spotify:artist:6qYaOvOcVHWkOUt7GYC2AD
# Loading missing artist: spotify:artist:6qYaOvOcVHWkOUt7GYC2AD
# Artist not in Artist Table: spotify:artist:2eQPDhVoSa5aeWROa5wfxZ
# Artist not in Artist Table: spotify:artist:0TJqjUyiiT1yckuKKASNMa
# Artist not in Artist Table: spotify:artist:7sLgqMMl7lWfWa69ABZds1
# Artist not in Artist Table: spotify:artist:0X39AZoCeledEiyQh0BDzW
# Loading missing artist: spotify:artist:0X39AZoCeledEiyQh0BDzW
# Artist not in Artist Table: spotify:artist:0Ncq7Ds6DGXLPBAcg03ZNb
# Loading missing artist: spotify:artist:0Ncq7Ds6DGXLPBAcg03ZNb
# Artist not in Artist Table: spotify:artist:0ZW4cdtA7Heht5HC7xrIIj
# Loading missing artist: spotify:artist:0ZW4cdtA7Heht5HC7xrIIj
# Artist not in Artist Table: spotify:artist:0u5GpuQQC8Vr2l648shvcC
# Loading missing artist: spotify:artist:0u5GpuQQC8Vr2l648shvcC
# Artist not in Artist Table: spotify:artist:32Y5gqewPZtbgYKyhoXbrT
# Loading missing artist: spotify:artist:32Y5gqewPZtbgYKyhoXbrT
# Artist not in Artist Table: spotify:artist:0PXHJsAO5ZQsiCgm39T50v
# Loading missing artist: spotify:artist:0PXHJsAO5ZQsiCgm39T50v
# Artist not in Artist Table: spotify:artist:1FjeDelzvqDfBffoHwsQkE
# Artist not in Artist Table: spotify:artist:1IibV6YF1Z2QI712E7f0yT
# Loading missing artist: spotify:artist:1IibV6YF1Z2QI712E7f0yT
# Artist not in Artist Table: spotify:artist:438xT3klM2P7FtrgHgqdyC
# Loading missing artist: spotify:artist:438xT3klM2P7FtrgHgqdyC
# Artist not in Artist Table: spotify:artist:5QushsnrPrAb50NiwaJt6z
# Loading missing artist: spotify:artist:5QushsnrPrAb50NiwaJt6z
# Artist not in Artist Table: spotify:artist:6J2nKHycSi7quTOMokXxIe
# Loading missing artist: spotify:artist:6J2nKHycSi7quTOMokXxIe
# Artist not in Artist Table: spotify:artist:4QV2j0EAbYJ2KcAFKaItuU
# Loading missing artist: spotify:artist:4QV2j0EAbYJ2KcAFKaItuU
# Artist not in Artist Table: spotify:artist:6mQ6biniRsyq5Ky3wKmAap
# Artist not in Artist Table: spotify:artist:0HvzuhtjsgvEQAt1EiqDCg
# Loading missing artist: spotify:artist:0HvzuhtjsgvEQAt1EiqDCg
# Artist not in Artist Table: spotify:artist:3Dwuw5gXVquhQOyRgYSSJi
# Loading missing artist: spotify:artist:3Dwuw5gXVquhQOyRgYSSJi
# Artist not in Artist Table: spotify:artist:2SaTzSab5n5Iq66aesvYzl
# Loading missing artist: spotify:artist:2SaTzSab5n5Iq66aesvYzl
# Artist not in Artist Table: spotify:artist:6VNCLDiRqBuZXq2nZ3PF3I
# Loading missing artist: spotify:artist:6VNCLDiRqBuZXq2nZ3PF3I
# Artist not in Artist Table: spotify:artist:6JYedwPn7zEWlTSUda9mev
# Artist not in Artist Table: spotify:artist:4Bzmpo45qE4xAOpcYYMy2h
# Loading missing artist: spotify:artist:4Bzmpo45qE4xAOpcYYMy2h
# token():INFO:   Token refreshed
# Artist not in Artist Table: spotify:artist:6KUGSbxgaKJR2Abxh85Ilv
# Artist not in Artist Table: spotify:artist:4UmwkIWyzQdm6OcqhJnMHu
# Loading missing artist: spotify:artist:4UmwkIWyzQdm6OcqhJnMHu
# Artist not in Artist Table: spotify:artist:2nLXsOG9ef284iyr1YhD1K
# Loading missing artist: spotify:artist:2nLXsOG9ef284iyr1YhD1K
# Artist not in Artist Table: spotify:artist:13v1TL8TUvBR1JQdmPtl12
# Loading missing artist: spotify:artist:13v1TL8TUvBR1JQdmPtl12
# Artist not in Artist Table: spotify:artist:4UN6S7QiOGY5beO7ERDy8Y
# Loading missing artist: spotify:artist:4UN6S7QiOGY5beO7ERDy8Y
# Artist not in Artist Table: spotify:artist:60AJE1gat83p4rB7UZCspu
# Loading missing artist: spotify:artist:60AJE1gat83p4rB7UZCspu
# Artist not in Artist Table: spotify:artist:0ebCuJrS2PS2NjAKe9XqYu
# Loading missing artist: spotify:artist:0ebCuJrS2PS2NjAKe9XqYu
# Artist not in Artist Table: spotify:artist:4ylYYxcluW7IKXpV9DDHSF
# Loading missing artist: spotify:artist:4ylYYxcluW7IKXpV9DDHSF
# Artist not in Artist Table: spotify:artist:1u88vrRlJSMtOqP6ulmeCc
# Artist not in Artist Table: spotify:artist:2vDZjbdDkuubd20Ltv4MC8
# Loading missing artist: spotify:artist:2vDZjbdDkuubd20Ltv4MC8
# Artist not in Artist Table: spotify:artist:2JcB0D3GGG5BhIJDkdtXi7
# Artist not in Artist Table: spotify:artist:1NLy01lQ3IWiqdzH33TSAB
# Loading missing artist: spotify:artist:1NLy01lQ3IWiqdzH33TSAB
# Artist not in Artist Table: spotify:artist:2J0TXJifL8vZUk11Bc7fGE
# Artist not in Artist Table: spotify:artist:623KR0v0jnzVnW1q1NNSd2
# Loading missing artist: spotify:artist:623KR0v0jnzVnW1q1NNSd2
# Artist not in Artist Table: spotify:artist:2k0CTSpfHwzEfYnQwNIiHq
# Loading missing artist: spotify:artist:2k0CTSpfHwzEfYnQwNIiHq
# Artist not in Artist Table: spotify:artist:4bfi4eUh8zh1AaPR3aiXnS
# Loading missing artist: spotify:artist:4bfi4eUh8zh1AaPR3aiXnS
# Artist not in Artist Table: spotify:artist:34GUpcsiQPpyaFhXVrZwsv
# Loading missing artist: spotify:artist:34GUpcsiQPpyaFhXVrZwsv
# Artist not in Artist Table: spotify:artist:0IQQvVcg8yGxrkQsTZjxMO
# Loading missing artist: spotify:artist:0IQQvVcg8yGxrkQsTZjxMO
# Artist not in Artist Table: spotify:artist:3OEmdcVuuuLIjT4MhUxStd
# Loading missing artist: spotify:artist:3OEmdcVuuuLIjT4MhUxStd
# Artist not in Artist Table: spotify:artist:3bBoSwGivxSBEYfmgP2nF3
# Loading missing artist: spotify:artist:3bBoSwGivxSBEYfmgP2nF3
# Artist not in Artist Table: spotify:artist:1yDtCDig6uJuvZRA5FGrPf
# Loading missing artist: spotify:artist:1yDtCDig6uJuvZRA5FGrPf
# Artist not in Artist Table: spotify:artist:0LWdHDPmZxRX7xLBBbyJWv
# Spotify returned None for track uri: spotify:track:0ZtckWScaCcgqmAK3NMwi4
# Artist not in Artist Table: spotify:artist:78bRdmU2YSGsP5EdPpGEGf
# Artist not in Artist Table: spotify:artist:1gYNfm9BVABco3sbwRUTGt
# Loading missing artist: spotify:artist:1gYNfm9BVABco3sbwRUTGt
# Artist not in Artist Table: spotify:artist:3B9OdGoXe2DUwoNJq3N9qY
# Artist not in Artist Table: spotify:artist:1ZEPSHuugQhNurpnSiTvaf
# Artist not in Artist Table: spotify:artist:4QQPuFwzBrJ9dE3GE3LJw4
# Loading missing artist: spotify:artist:4QQPuFwzBrJ9dE3GE3LJw4
# Artist not in Artist Table: spotify:artist:1hs7RpMb0jSl4GiBDsbbS5
# Loading missing artist: spotify:artist:1hs7RpMb0jSl4GiBDsbbS5
# Artist not in Artist Table: spotify:artist:32Y5gqewPZtbgYKyhoXbrT
# Artist not in Artist Table: spotify:artist:2VvKZTmM6waQ64A1erQkto
# Artist not in Artist Table: spotify:artist:04R1xWRUHaMdY8S9Req4iq
# Artist not in Artist Table: spotify:artist:2CSTWS9xKp1fzPGdbsGQ0D
# Loading missing artist: spotify:artist:2CSTWS9xKp1fzPGdbsGQ0D
# Artist not in Artist Table: spotify:artist:72iDlGYfVrntfpKzmAv0Hn
# Loading missing artist: spotify:artist:72iDlGYfVrntfpKzmAv0Hn
# Artist not in Artist Table: spotify:artist:2sVthFU8L5tg2wBK7y2u9l
# Artist not in Artist Table: spotify:artist:3om4sgf4FSfBhk1sNPKTYM
# Loading missing artist: spotify:artist:3om4sgf4FSfBhk1sNPKTYM
# Artist not in Artist Table: spotify:artist:1PYDPIfSdLd9ana66eUiNH
# Loading missing artist: spotify:artist:1PYDPIfSdLd9ana66eUiNH
# Artist not in Artist Table: spotify:artist:0lcIRzEVZTKyNiEct4UKTo
# Loading missing artist: spotify:artist:0lcIRzEVZTKyNiEct4UKTo
# Artist not in Artist Table: spotify:artist:2bnAwYDwoViEbH8gcd6kbA
# Loading missing artist: spotify:artist:2bnAwYDwoViEbH8gcd6kbA
# Artist not in Artist Table: spotify:artist:5JJHnW1bhWbA3Slljbdktc
# Loading missing artist: spotify:artist:5JJHnW1bhWbA3Slljbdktc
# Artist not in Artist Table: spotify:artist:4DKpMK51PbY3Gz5aLudFJY
# Loading missing artist: spotify:artist:4DKpMK51PbY3Gz5aLudFJY
# Artist not in Artist Table: spotify:artist:5vKcamfzZfWcYyWJMFIRbh
# Loading missing artist: spotify:artist:5vKcamfzZfWcYyWJMFIRbh
# Artist not in Artist Table: spotify:artist:5VX4tEDuzOJVEHyZoO1zKF
# Loading missing artist: spotify:artist:5VX4tEDuzOJVEHyZoO1zKF
# Artist not in Artist Table: spotify:artist:2AjSYIqajsunXAn3B4tF9w
# Artist not in Artist Table: spotify:artist:3GyulobYMarjGVq1DTx0Uj
# Loading missing artist: spotify:artist:3GyulobYMarjGVq1DTx0Uj
# Artist not in Artist Table: spotify:artist:6BzXWtIQa40aZWK3PneVLO
# Loading missing artist: spotify:artist:6BzXWtIQa40aZWK3PneVLO
# Artist not in Artist Table: spotify:artist:1nw2FrrnONJ3TKqF2IfXmm
# Loading missing artist: spotify:artist:1nw2FrrnONJ3TKqF2IfXmm
# Artist not in Artist Table: spotify:artist:1YrZXTT03tbY3MFNXQ47MJ
# Loading missing artist: spotify:artist:1YrZXTT03tbY3MFNXQ47MJ
# Artist not in Artist Table: spotify:artist:6g0F8TkDWopePVJuwo6jsL
# Loading missing artist: spotify:artist:6g0F8TkDWopePVJuwo6jsL
# Artist not in Artist Table: spotify:artist:7AOaJM06LzJhWJEBFHRNPr
# Artist not in Artist Table: spotify:artist:1ulE3crG8MWZts62ujwfCF
# Loading missing artist: spotify:artist:1ulE3crG8MWZts62ujwfCF
# Artist not in Artist Table: spotify:artist:15V0tfNc0zJQ3rwtpuhDb2
# Artist not in Artist Table: spotify:artist:4thfsgmluRHQutMgPrr8yq
# Artist not in Artist Table: spotify:artist:2t1Nk9gOYeowos2dFu8rTl
# Artist not in Artist Table: spotify:artist:1HABXfQw50qg2WnUlgz4M8
# Loading missing artist: spotify:artist:1HABXfQw50qg2WnUlgz4M8
# Spotify returned None for track uri: spotify:track:0tQBcMmEpyHX7UEDtGAbXk
# Artist not in Artist Table: spotify:artist:0IgK5pCxVmRVCqL70xTy1w
# Loading missing artist: spotify:artist:0IgK5pCxVmRVCqL70xTy1w
# Artist not in Artist Table: spotify:artist:2FKu3PbwMoyEKO6qhZ4nog
# Loading missing artist: spotify:artist:2FKu3PbwMoyEKO6qhZ4nog
# Artist not in Artist Table: spotify:artist:7BouKelHMxy42RJSMzkE0w
# Artist not in Artist Table: spotify:artist:57Jy7fPyLhL3XaMRfjEfez
# Loading missing artist: spotify:artist:57Jy7fPyLhL3XaMRfjEfez
# Artist not in Artist Table: spotify:artist:3yAhQr8f1rV1HCs5OIh3d2
# Loading missing artist: spotify:artist:3yAhQr8f1rV1HCs5OIh3d2
# Artist not in Artist Table: spotify:artist:1PBuUzNkU3O6mXliO7Mpih
# Loading missing artist: spotify:artist:1PBuUzNkU3O6mXliO7Mpih
# Artist not in Artist Table: spotify:artist:2ObH0XSPq81UuZizP2a0UQ
# Artist not in Artist Table: spotify:artist:0owXTrjMw627VyAGFrHyRR
# Loading missing artist: spotify:artist:0owXTrjMw627VyAGFrHyRR
# Artist not in Artist Table: spotify:artist:0yJj8wI4GqLvwLpPkjk0mA
# Artist not in Artist Table: spotify:artist:5v4u4iPkDu5urrAuFTlihR
# Loading missing artist: spotify:artist:5v4u4iPkDu5urrAuFTlihR
# Artist not in Artist Table: spotify:artist:7y3ULlnKKpeZ4JOKMAJQzK
# Loading missing artist: spotify:artist:7y3ULlnKKpeZ4JOKMAJQzK
# Artist not in Artist Table: spotify:artist:1zmx3NwOp6vR4qEjmhSiLL
# Artist not in Artist Table: spotify:artist:5qlsQY2vomOprDK5p84I1n
# Loading missing artist: spotify:artist:5qlsQY2vomOprDK5p84I1n
# Artist not in Artist Table: spotify:artist:3BYuli0zAGgTeoH9m9kB1J
# Artist not in Artist Table: spotify:artist:53vKHY402CWQ7zS39i0CyW
# Spotify returned None for track uri: spotify:track:4oK7iW1UVjoiSSkZhaYKHO
# Artist not in Artist Table: spotify:artist:4bjlAhaEyLSRWA8iXT5kaz
# Loading missing artist: spotify:artist:4bjlAhaEyLSRWA8iXT5kaz
# Artist not in Artist Table: spotify:artist:5W3VyozqzfTUBYBE5BFePa
# Loading missing artist: spotify:artist:5W3VyozqzfTUBYBE5BFePa
# Artist not in Artist Table: spotify:artist:0OCgRH2JnfJo0nNDJzEG0Q
# Artist not in Artist Table: spotify:artist:4ji5Qb4IMB5yeiXhO1SE9d
# Loading missing artist: spotify:artist:4ji5Qb4IMB5yeiXhO1SE9d
# Artist not in Artist Table: spotify:artist:082Dgc31gwjrkfsbXWgps0
# Loading missing artist: spotify:artist:082Dgc31gwjrkfsbXWgps0
# Artist not in Artist Table: spotify:artist:6BVjnrhoq9PZDHIkjRaV3M

# %%
# Some tracks returned "None" from Spotify
# These need to be removed from the playlist table and the audio_features table
none_tracks_list = ['spotify:track:1pTy8JZSD7UTU5Xg4Cs8VX', 
                    'spotify:track:05iPvBxNaTbMi1twl3rnTJ',
                    'spotify:track:2nOyWmvoS9AffQFUc9I7v0',
                    'spotify:track:11NIehXWtiykABhxSCRwFI',
                    'spotify:track:7sRmheYLtEzJtc2MeVbT6F',
                    'spotify:track:4WHjf37BBXUo3WYBmJPdoU',
                    'spotify:track:0KiU8DYL1oUZP0MrEHC5CS',
                    'spotify:track:0jcNaEKRJSwdW1Oz7LvuG7',
                    'spotify:track:5nxkWaHFSqk1ep5wS3WelK',
                    'spotify:track:2rGNgMHMn9NvjeoUCX2wc4',
                    'spotify:track:0crHjy8Lrvkz7oPPRq1L6E',
                    'spotify:track:5wWSOTMSqYUGFJ5Fl599LI',
                    'spotify:track:1SuyTHBUdlsDJeZ77viTVY',
                    'spotify:track:18JnPuzORjaFXgdcVJWjjI',
                    'spotify:track:5mbnHTT20qMKEbj31NmpHF',
                    'spotify:track:6cePxNkX02pGoQHhiVohO1',
                    'spotify:track:5WJ2L1bDMN2mXiwyQaXUz0',
                    'spotify:track:0zA7okPLt66GVf2ilDN9Eq',
                    'spotify:track:3o9RCvd6Vg8wD8b9SLBhDr',
                    'spotify:track:35yeDq2AngBhej5A3qNnpX',
                    'spotify:track:6UnswPYevOy5rxgZPslKGn',
                    'spotify:track:14FXVh0pq4KjGzzSsHfSoy',
                    'spotify:track:3naqPs5OCvHpl6c3ViHIqu',
                    'spotify:track:4BivwSVjlIZiRIPvxBk5s7',
                    'spotify:track:1XOmeD5yaCCwjqOtX2eEi2',
                    'spotify:track:2Gu5evIIp7KyXbhqEnL6YC',
                    'spotify:track:20fm88MHpkoqTUDCsHM3na',
                    'spotify:track:41SsTPHM7NWmNAorFRIirw',
                    'spotify:track:3nrZjTJT5BM5bXGPVZlOrp',
                    'spotify:track:15U8rfkO57LOjrq7BYieMN',
                    'spotify:track:3M1r36fZnWXbTXYSvM5B0x',
                    'spotify:track:7DFlVLqLufZkIPwU4v4SjA',
                    'spotify:track:5qzY4R9MDaHeNqIfQ6COTO',
                    'spotify:track:0BmzHs9pzTEzPrIincgybc',
                    'spotify:track:3shKUOchFxWHrFJbBMPNzW',
                    'spotify:track:0SSC0sePHmluTebCPRGJFc',
                    'spotify:track:62rhiYfhHwWco2L8CG4dxH',
                    'spotify:track:7FRoiXM7YRZ2wsKBlWZ9nR',
                    'spotify:track:5GiU7GOYjDH2yp7fMf9w9j',
                    'spotify:track:1bOeJnwdyA1MIsNH5KE9jW',
                    'spotify:track:4vjgGKKctk8BPui1TcymNd',
                    'spotify:track:7Aq04R5A0U0kGmwsbFCCiH',
                    'spotify:track:0msQOLNzGMKihyNXMkLL8x',
                    'spotify:track:5BRT6U0jtwvRJQHObtL5HZ',
                    'spotify:track:0yrKM7TtOWDJQtFXv2UjYq',
                    'spotify:track:4GBC5hRigIgKFpsPsF0YyH',
                    'spotify:track:3e3RrqJidaVj2EFxCECYjD',
                    'spotify:track:0ZtckWScaCcgqmAK3NMwi4',
                    '',
                    '',
                    '',
                    '',
                    '',
                    '',
                    '',
                    '',
                    '',
                    '',
                    '',
                    '',
                   ]

# double check to make sure this is correct
sp_tracks = get_tracks(none_tracks_list)

problem = False
for sp_t in sp_tracks:
    if sp_t != None:
        print("Problem: {} is not None!".format(sp_t))
        problem = True

if not problem:
    print("All tracks returned None - Remove them from the database")
